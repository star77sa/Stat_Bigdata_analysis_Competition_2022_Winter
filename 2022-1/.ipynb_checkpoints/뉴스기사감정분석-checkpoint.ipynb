# %% [markdown]
# https://somjang.tistory.com/entry/Keras%EA%B8%B0%EC%82%AC-%EC%A0%9C%EB%AA%A9%EC%9D%84-%EA%B0%80%EC%A7%80%EA%B3%A0-%EA%B8%8D%EC%A0%95-%EB%B6%80%EC%A0%95-%EC%A4%91%EB%A6%BD-%EB%B6%84%EB%A5%98%ED%95%98%EB%8A%94-%EB%AA%A8%EB%8D%B8-%EB%A7%8C%EB%93%A4%EC%96%B4%EB%B3%B4%EA%B8%B0

# %%
import os

import numpy as np 
import pandas as pd
import os
import glob
import re
import sys
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import matplotlib.pylab as plt
from matplotlib import animation, rc
import seaborn as sns

import plotly.express as px
import folium
from folium import plugins
import branca
import json

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots


pio.renderers.default = "notebook_connected"

# %%
os.chdir('G:/내 드라이브/Github/Stat_Bigdata_analysis_Competition_2022/2022-1/Data')

# %%
# train_data = pd.read_csv("./외부/train.csv")
# test_data = pd.read_csv("./외부/test2.csv")

# %%
data = pd.read_csv("./외부/코로나_00.csv")
data = data.drop('Unnamed: 0', axis = 1)

train_data = data[0:800]
test_data = data[800:1000]

# %%
with open("./외부/negative_words_self.txt", encoding = 'utf-8') as neg:
    negative = neg.readlines()
    
negative = [neg.replace("\n", "") for neg in negative]

with open("./외부/positive_words_self.txt", encoding='utf-8') as pos:
    positive = pos.readlines()
    
positive = [pos.replace("\n", "") for pos in positive]

# %%
# train_data = train_data.drop("Unnamed: 0", axis=1)
# test_data = test_data.drop("Unnamed: 0", axis=1)
# test_data = test_data.drop("Unnamed: 0.1", axis=1)

# %%
from tqdm import tqdm
import re

labels = []

title_data = list(test_data['title'])

for title in tqdm(title_data):
  clean_title = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…\"\“》]', '', str(title)) 
  negative_flag = False
  label = 0
  for i in range(len(negative)):
    if negative[i] in clean_title:
      label = -1
      negative_flag = True
      print("negative 비교단어 : ", negative[i], "clean_title : ", clean_title) 
      break
  if negative_flag == False:
    for i in range(len(positive)):
      if positive[i] in clean_title:
        label = 1
        print("positive 비교단어 : ", positive[i], "clean_title : ", clean_title)
        break

  labels.append(label)

test_data['label'] = labels
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 28580.31it/s]
# negative 비교단어 :  취약 clean_title :  연산6동 취약계층 행복비타민 나눔 사업 실시
# positive 비교단어 :  체결 clean_title :  김해시 스마트 건강관리서비스 운영을 위한 업무협약 체결
# negative 비교단어 :  기소 clean_title :  김학의 출금 관여’ 기소된 이광철 사의검찰 부당한 결정”
# positive 비교단어 :  최고 clean_title :  경기도민들 민선7기 코로나 대응 최고 잘했다
# negative 비교단어 :  논란 clean_title :  ESC 한복은 경쟁 속에서 진화 중원조 논란 답답해”
# negative 비교단어 :  논란 clean_title :  홍남기·이주열 2일 조찬회동엇박자 논란 재정·통화정책 조율할듯
# positive 비교단어 :  돌파 clean_title :  상반기 수출 사상 첫 3000억달러 돌파
# negative 비교단어 :  논란 clean_title :  재난지원금 소득하위 80 1인당 25만원건보료 기준 지역가입자 차별 논란
# negative 비교단어 :  우려 clean_title :  대구·경북 사적 모임 최대 8인까지기대 반 우려 반’
# positive 비교단어 :  봉사 clean_title :  영동군자원봉사센터 벽화 그리기로 마을주민 웃음꽃 선물
# negative 비교단어 :  우려 clean_title :  정은경 미접종 2030 확진 늘어 거리두기 완화시 폭발적 증가 우려
# positive 비교단어 :  증가 clean_title :  정은경 거리두기 완화시 유행 폭발적 증가할 수도”
# positive 비교단어 :  1위 clean_title :  현대백화점 대구점 작년 지역기여도 평가 1위
# positive 비교단어 :  미소 clean_title :  포토뉴스 다시 만난 환한 미소
# positive 비교단어 :  체결 clean_title :  한국유가공협회와 Thank 유 캠페인’ 사업관련 협약식 체결
# negative 비교단어 :  피해 clean_title :  속보 코로나 손실보상법 국회 통과소급적용 없이 피해지원
# negative 비교단어 :  피해 clean_title :  국회 코로나19 손실보상법 통과소급 적용’ 빠진 대신 피해 지원’
# negative 비교단어 :  호소 clean_title :  올림픽에 모유 수유 아기 동행해야 캐나다 선수 호소
# negative 비교단어 :  피해 clean_title :  코로나 손실보상법 국회 본회의 통과소급적용 대신 피해지원으로
# positive 비교단어 :  증가 clean_title :  기아 6월 글로벌 판매 25만3592대전년비 202 증가
# positive 비교단어 :  수상 clean_title :  재창원산업진흥원 수소대상연구기관 부문 수상
# positive 비교단어 :  최고 clean_title :  올 종가 최고치 경신 코스닥 소외가 사라진다
# negative 비교단어 :  논란 clean_title :  선별검사 논란 청주 A 초등학교 체육 수업 통합 운영 빈축
# negative 비교단어 :  기소 clean_title :  ​종합 이광철 靑 민정비서관 결국 사표부당한 기소 유감”
# negative 비교단어 :  논란 clean_title :  구례군의회 코로나19 시국 혈세낭비 제주도 황제연수 논란
# positive 비교단어 :  1위 clean_title :  뉴있저 지지율 1위 이재명 출마 선언본격 레이스 막 올라
# negative 비교단어 :  우려 clean_title :  올여름 전력수요 역대 최고 예상정전 등 대란 우려
# negative 비교단어 :  논란 clean_title :  현장메모 한국인봉’ 논란 부채질하는 샤넬의 가격 인상
# positive 비교단어 :  트렌드 clean_title :  홍순철의 글로벌 북 트렌드 25세 축구선수가 전한 선한 영향력
# negative 비교단어 :  피해 clean_title :  2020년 8월 이후 방역 조처로 피해 본 소상공인·소기업에 100만∼900만원 지원
# <ipython-input-7-a810466e9aff>:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from tqdm import tqdm
import re

labels = []

title_data = list(train_data['title'])

for title in tqdm(title_data):
  clean_title = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…\"\“》]', '', str(title)) 
  negative_flag = False
  label = 0
  for i in range(len(negative)):
    if negative[i] in clean_title:
      label = -1
      negative_flag = True
      print("negative 비교단어 : ", negative[i], "clean_title : ", clean_title) 
      break
  if negative_flag == False:
    for i in range(len(positive)):
      if positive[i] in clean_title:
        label = 1
        print("positive 비교단어 : ", positive[i], "clean_title : ", clean_title)
        break

  labels.append(label)

train_data['label'] = labels
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<00:00, 29630.47it/s]
# negative 비교단어 :  우려 clean_title :  폭염에 올 여름 전력수요 사상 최고치 전망삐끗하면 정전 우려
# positive 비교단어 :  돌파 clean_title :  상반기 수출 3000억달러 돌파반도체·친환경 날개 달고 올해 역대급 실적 전망
# negative 비교단어 :  우려 clean_title :  7월 1000만회분 백신 도입희귀 혈전증 우려에 AZ는 50세 이상만 접종
# negative 비교단어 :  위반 clean_title :  수원시 코로나19 방역 수칙 위반 업소 적발
# positive 비교단어 :  증가 clean_title :  대학 비대면 강의 코로나 이후 28배 증가
# positive 비교단어 :  기부 clean_title :  법무부 법사랑 인천 서구위원회 검단노인복지관에 마스크 1만장 기부
# negative 비교단어 :  기소 clean_title :  김학의 출금 관여’ 기소된 이광철 사의검찰 부당한 결정”
# negative 비교단어 :  우려 clean_title :  강원 17개 시군 전면 등교우려 속 일상 복귀
# negative 비교단어 :  우려 clean_title :  강원 15개 시군 모임 인원 제한 해제우려 여전
# negative 비교단어 :  우려 clean_title :  대구·경북 사적 모임 최대 8인까지기대 반 우려 반’
# positive 비교단어 :  주목 clean_title :  캠핑용품 일단 예뻐야감성캠핑 인기에 관련상품·굿즈 주목
# positive 비교단어 :  봉사 clean_title :  금성백조 예미지 사랑나눔 봉사단 국가유공자 노후주택 무료보수 실시
# negative 비교단어 :  중단 clean_title :  세븐틴 에스쿱스 어깨 부상으로 미니 8집 활동 중단 안정 취하는 중
# negative 비교단어 :  우려 clean_title :  올여름 전력수요 역대 최고치 예상 대란 우려
# negative 비교단어 :  급감 clean_title :  학령인구 급감 과세 증가 경쟁위주 평가 대학 총장들 생존 위협
# positive 비교단어 :  체결 clean_title :  Thank 유 캠페인’ 한국유가공협회 대한적십자사 아트펌컴퍼니 공동주관 참여 협약 체결
# negative 비교단어 :  우려 clean_title :  정은경 델타변이 수도권거리두기 완화 시 폭발적 유행 우려
# negative 비교단어 :  우려 clean_title :  종합 거리두기 연장 필요성↑···수도권 델타 변이’ 확산에 우려
# positive 비교단어 :  오픈 clean_title :  미노벨 웹소설 자유연재 플랫폼 베타 서비스 오픈
# positive 비교단어 :  증가 clean_title :  현대차 6월 35만4409대 판매전년비 144 증가
# negative 비교단어 :  반토막 clean_title :  52시간제에 반토막 난 월급中企 근로자들 알바 뜁니다
# positive 비교단어 :  돌파 clean_title :  도쿄 확진자 700명 돌파스가 무관중 올림픽 있을 수도”
# negative 비교단어 :  산재 clean_title :  프로필 이상균 수원시 예산재정과장 外
# negative 비교단어 :  우려 clean_title :  정은경 수도권서 델타변이까지거리두기 완화시 폭발적 증가 우려
# positive 비교단어 :  제휴 clean_title :  오스틴제약 삼성제약과 제휴 일반의약품 사업 진출
# negative 비교단어 :  피해 clean_title :  여기는 충주 재건축 기대감에 가격 들썩규제 피해 제천으로
# positive 비교단어 :  증가 clean_title :  기저효과 현대차 6월판매 144 증가수출 덕에 웃었다
# positive 비교단어 :  이목 clean_title :  규제 피한 고품격 하이엔드 단독주택 단지 그랑빌 더 포레’ 이목 집중
# positive 비교단어 :  1위 clean_title :  트럼프 美 대통령 리더십 평가’서 44명 중 41위
# negative 비교단어 :  우려 clean_title :  국민 77 여름휴가 활동 자제해야코로나19 확산 우려
# positive 비교단어 :  인기 clean_title :  경기도장애인기능경기대회 145명 선수 자웅 겨룬다
# negative 비교단어 :  매각 clean_title :  레이더M 신한대체운용 골프장 매각으로 대박IRR 70
# positive 비교단어 :  새로운 clean_title :  기고문 원격운영으로 물류산업의 새로운 자동화시대를 열다
# positive 비교단어 :  1위 clean_title :  코로나 뚫고 생산 동화 베트남 중밀도섬유판MDF 시장 1위 굳힌다
# negative 비교단어 :  일탈 clean_title :  황교안 대선 출마선언 문 정권 일탈 정상으로 돌려놓겠다”
# positive 비교단어 :  오픈 clean_title :  일화 제7회 KLPGA 맥콜·모나파크 오픈 with SBS Golf’ 개최
# negative 비교단어 :  우려 clean_title :  터키 끝내 이스탄불 협약 탈퇴여성인권 퇴보 우려
# negative 비교단어 :  논란 clean_title :  소급적용’ 빠진 손실보상법 통과됐다국가교육위도 논란 끝 통과
# negative 비교단어 :  우려 clean_title :  비수도권 오늘부터 1단계기대 높은 만큼 우려도
# positive 비교단어 :  대세 clean_title :  김정은 적대세력의 中압박은 발악” 시진핑에 축전 보내 밀착 과시
# negative 비교단어 :  매각 clean_title :  은성수 금융위원장 씨티은행 가능하다면 통매각 희망
# negative 비교단어 :  호소 clean_title :  132개 대학총장들 호소 저출산·코로나 위기정부 지원 늘려야
# negative 비교단어 :  중단 clean_title :  한국산업인력공단 장기 중단된 산업잠수사 시험 재개
# negative 비교단어 :  피해 clean_title :  세계 코로나 사망자 400만명미국 사망자 62만명으로 최대 피해
# negative 비교단어 :  빨간불 clean_title :  자녀들 등교 중지’·집콕’ 장기화부모들 정신건강 빨간불’
# positive 비교단어 :  출시 clean_title :  GNI개나리벽지 바이러스와 세균 완벽 차단하는 에비뉴’ 리뉴얼 출시해
# positive 비교단어 :  봉사 clean_title :  담이랑 가족봉사단 벽화그리기로 마을주민들에 웃음꽃 선물
# positive 비교단어 :  돌파 clean_title :  6월 수출 397↑상반기 첫 3000억 달러 돌파
# positive 비교단어 :  기부 clean_title :  도백 월급 기부로 시작된 나눔 청년들에겐 꿈’
# positive 비교단어 :  돌파 clean_title :  캠코 온비드 누적 거래금액 90조 돌파
# positive 비교단어 :  MOU clean_title :  동국제강 SK에코플랜트와 안심건축자재 사용 확대 위한 MOU 체결
# positive 비교단어 :  돌파 clean_title :  코트라 올해 수출 6000억 달러 돌파하반기도 수출 호조”
# positive 비교단어 :  착한 clean_title :  속초시 착한 임대인’ 재산세 감면
# positive 비교단어 :  돌파 clean_title :  캠코 온비드 누적거래금액 90조원 돌파회원 222만명 달해
# negative 비교단어 :  취약 clean_title :  전문가 우리나라 델타 변이’ 취약한 이유는”
# positive 비교단어 :  돌파 clean_title :  상반기 수출액 첫 3000억 달러 돌파 15개 주력 품목 모두 늘었다
# positive 비교단어 :  주목 clean_title :  마켓인사이트장동헌 행정공제회 CIO 전통적 자산배분 공식 이젠 안 통해메인 떠오른 니치 자산에 주목해야
# negative 비교단어 :  매각 clean_title :  강원포럼알펜시아 매각과 과제
# positive 비교단어 :  착한 clean_title :  속초착한 임대인 재산세 감면
# negative 비교단어 :  위반 clean_title :  미군 난동 차단” 해운대 방역수칙 위반 특별단속
# negative 비교단어 :  우려 clean_title :  사설 새 거리두기 첫날 반가움보다 우려 앞선다
# negative 비교단어 :  취약 clean_title :  기초학력 부진·교육취약층 학생 집중 지원을
# positive 비교단어 :  수상 clean_title :  강서 코로나 위기관리 공모대회’ 대상 수상
# positive 비교단어 :  순항 clean_title :  분양 포커스 2100만원대 한강뷰·숲세권  부분철거 시작 착공까지 순항 예고
# negative 비교단어 :  불만 clean_title :  이 시국에 웬 한중해저터널 양승조 공약에 네티즌 불만 폭발
# positive 비교단어 :  수상 clean_title :  오피스넥스 특수상권 가맹점엔 임차료 50 지원
# positive 비교단어 :  최고 clean_title :  광공업·서비스업은 줄었는데 공공행정만 백신발 7년來 최고
# negative 비교단어 :  산재 clean_title :  산재전문 공공병원 설립·울산외곽순환도로 개설 큰 성과”
# negative 비교단어 :  우려 clean_title :  대중음악 공연 기지개확진자 증가에 우려도 커져
# positive 비교단어 :  최고 clean_title :  코스피 최고가 달리자 곱버스 탄 개미들어라 또 오르네
# positive 비교단어 :  돌파 clean_title :  상반기 수출 사상 첫 3000억불 돌파6월 수출만 40 급증
# negative 비교단어 :  우려 clean_title :  원자잿값·물류비 상승·인플레이션 우려
# negative 비교단어 :  닫아 clean_title :  울산 산업생산 회복 더디고 소비자는 지갑 닫아
# negative 비교단어 :  취약 clean_title :  한국수력원자력주 새울원자력본부 취약층 250가구에 서생멸치 선물
# positive 비교단어 :  봉사 clean_title :  평창군건강위 주민 건강증진·코로나 방역봉사 앞장
# negative 비교단어 :  적발 clean_title :  안성시 일대 유흥주점서 불법취업 외국인 접객원 12명 적발
# positive 비교단어 :  돌파 clean_title :  상반기 수출 사상 첫 3000억弗 돌파연간 수출도 최고치 전망
# negative 비교단어 :  폐업 clean_title :  동작구 집합금지·영업제한 업종 폐업 소상공인 50만원 지원
# positive 비교단어 :  봉사 clean_title :  고대면 새마을부녀협의회 사랑담은 열무김치 봉사 펼쳐
# negative 비교단어 :  직격탄 clean_title :  대구 호텔업계 코로나 직격탄에다 각종 루머까지 사면초가
# negative 비교단어 :  논란 clean_title :  소득 하위 80에 재난지원금형평성 논란에 벌써 확대” 주장
# positive 비교단어 :  최고 clean_title :  스물다섯 생일상 받은 코스닥 21년만에 최고점 자축’
# negative 비교단어 :  논란 clean_title :  혈전 논란 AZ백신 50세 이상에만 접종 50세 미만 2차 접종은 화이자
# positive 비교단어 :  출시 clean_title :  유탑부티크호텔레지던스 호캉스 상품 출시
# negative 비교단어 :  우려 clean_title :  정은경 수도권 델타변이 확산거리두기 완화시 폭발적 유행 우려
# negative 비교단어 :  우려 clean_title :  뉴있저 오늘부터 비수도권 새 거리두기감염 확산 우려는
# positive 비교단어 :  입점 clean_title :  신세계 울산시민에 사과하고 백화점 입점 이행하라”
# positive 비교단어 :  수상 clean_title :  농협중앙회 울산본부 올해 2분기 범농협 사회공헌상 수상
# positive 비교단어 :  증가 clean_title :  WHO 유럽 확진자 다시 증가향후 새로운 유행 가능성 경고
# negative 비교단어 :  취약 clean_title :  美 연구진 남성이 코로나에 취약여성보다 중증 위험 높아
# negative 비교단어 :  울상 clean_title :  수도권은 울상 비수도권은 웃음거리두기 단계에 희비교차
# positive 비교단어 :  봉사 clean_title :  김성기 가평군수 민선7기 3주년 기념 백신접종센터 봉사 활동
# positive 비교단어 :  열풍 clean_title :  감정가 47억 짜리 남양주 땅이 40억에 낙찰토지·오피스텔도 경매 열풍 부동산360
# positive 비교단어 :  출시 clean_title :  씨젠 델타 포함 6개 코로나19 변이 찾아내는 진단시약 출시
# positive 비교단어 :  MOU clean_title :  중기중앙회산업인력공단 능력중심 인사체계 확산 MOU
# positive 비교단어 :  진출 clean_title :  영우디에스피 건양대와 손잡고 의료용 돌봄 로봇 시장 진출”
# negative 비교단어 :  초토화 clean_title :  델타 변이에 초토화됐다 시드니 파티장 30명 중 24명 감염백신 접종자는 피했다
# positive 비교단어 :  새로운 clean_title :  부산시 지역 성장을 위한 지산학 협력의 새로운 도약
# positive 비교단어 :  수상 clean_title :  소주 원조 진로 에피어워드 코리아 6개 부문 수상
# positive 비교단어 :  수상 clean_title :  예산군 2021 코로나 위기관리 대상 공모대회 최우수상 수상
# negative 비교단어 :  우려 clean_title :  이달말 전력수급 비상’ 발령 가능성 탈원전發 블랙아웃 우려
# positive 비교단어 :  봉사 clean_title :  담이랑 가족봉사단 벽화그리기로 마을주민들에 웃음꽃 선물
# negative 비교단어 :  소송 clean_title :  확진자 응시제한 임용고시생 국가배상 소송 첫 재판적법성 공방
# negative 비교단어 :  취약 clean_title :  스마트 건강관리’ 시스템으로 취약층 돌본다  고신대복음병원 안심관리’ 개발사업 선정
# negative 비교단어 :  허위 clean_title :  태영호 김정은 노발대발 군량미 허위보고 때문일 것
# positive 비교단어 :  증가 clean_title :  의료기기 특허출원 증가율 평균 출원율 보다 36배 높아
# positive 비교단어 :  진출 clean_title :  씨젠 美 바이오라드와 손잡고 미국 시장 진출 본격화
# negative 비교단어 :  싸늘 clean_title :  中 매체 공산당 인민 이끌고 포위망 뚫고 승리” 자화자찬홍콩·대만은 싸늘’
# positive 비교단어 :  최고 clean_title :  최고 스마트폰은 갤럭시S21 울트라아이폰 제쳤다
# positive 비교단어 :  증가 clean_title :  의료기기 특허출원 증가율 전체 특허출원 평균보다 36배 높아
# positive 비교단어 :  오픈 clean_title :  NH농협생명 모바일 청약 시스템 오픈
# positive 비교단어 :  최고 clean_title :  111년 만의 폭염 왔던 2018년 이후 전력 수요 최고치
# positive 비교단어 :  돌파 clean_title :  코로나 딛고 역대 최대 상반기 수출사상 첫 3000억불 돌파
# positive 비교단어 :  돌파 clean_title :  6월 수출 최고 기록상반기 수출 3천억 달러 첫 돌파
# negative 비교단어 :  취약 clean_title :  부원동지역사회보장협의체 취약계층 어르신 힐링 문화체험’ 추진
# positive 비교단어 :  기부 clean_title :  거제3동 청년회 창립 45주년 기념 소상공인에게 성금 기부
# positive 비교단어 :  유치 clean_title :  거제시 대기업 건설사 초청 투자유치설명회 개최
# positive 비교단어 :  1위 clean_title :  김정은 방역 내세워 대대적 숙청 軍서열 1위 리병철 해임된듯
# negative 비교단어 :  논란 clean_title :  적자국채 없지만 재정의존증 심화선별지원 기준 논란 점화2차 추경 국무회의 통과
# negative 비교단어 :  하락 clean_title :  목재 가격 6월 한달간 40 이상 하락월간 하락폭 역대 최대
# negative 비교단어 :  논란 clean_title :  적자국채 추가발행 없지만 재정의존증 심화선별지원 기준 등 논란 불가피 2차 추경
# positive 비교단어 :  돌파 clean_title :  천덕꾸러기 펀드의 귀환펀드 설정액 사상 첫 700조 돌파
# positive 비교단어 :  순항 clean_title :  새로운 거제 미래 10년 청사진 순항’
# <ipython-input-8-5957d42f7b34>:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
title_data
# Out:
# ['폭염에 올 여름 전력수요 사상 최고치 전망...삐끗하면 `정전` 우려',
#  '상반기 수출 3000억달러 돌파…반도체·친환경 날개 달고 올해 `역대급` 실적 전망',
#  '나라빚 1000조인데, 채무상환 고작 2조…전문가들 재정정상화 생색내기',
#  '국세청 신임 차장에 임광현',
#  '국세청 차장에 임광현…서울청장에 임성빈',
#  '신동빈 혁신이 살길…화학 신사업에 9조 투자',
#  "7월 1,000만회분 백신 도입…'희귀 혈전증 우려'에 AZ는 50세 이상만 접종",
#  '1만1,000명 프레시매니저 업고…물류사업 닻올린 hy',
#  '델타변이 확산에도…민노총 3일 서울에 1만명 모인다',
#  '‘인플레·델타 변이·연준’…하반기 美경제 3대 변수가 가른다',
#  '서구 언론 中, 적에게 확실한 경고 보내',
#  '김승연 한화 회장, 에드윈 퓰너 美 헤리티지 회장와 회동',
#  "中, 행사 참여 7만명 모두 '노 마스크'…스텔스기 에어쇼까지",
#  '진승호 KIC 사장 적극적 투자 수익 창출로 세계 10대 국부펀드 도약할 것',
#  '글로벌 관광·문화·과학도시 발돋움, 강릉 브랜드 파워 확대',
#  '사소한 약속',
#  '단양구경시장 구석구석 깨끗하게',
#  '세부 가이드라인 필요한 옥외영업',
#  '귀농의 꿈, 코로나도 막지 못해요',
#  "'지역 사랑' 충청투데이, 대전 체육 발전기금 1호 기탁 언론사 됐다",
#  '코로나·지방자치법 개정 선제 대응 성과',
#  '하태경 의원 “KAI 내부시스템, 北에 해킹”',
#  '제주도 올해 하반기 정기인사 1일 예고',
#  '[사설] 득보다 실이 더 커 보이는 6차 재난지원금',
#  '휴가철·델타변이 변수까지…또 대유행 올라 완화 급제동 [수도권 거리두기 1주일 연장]',
#  "열나는데 여행간 개인 등 대부분 '면피' 정부 차원 청구는 사랑제일교회 단 1건",
#  '수원시, 코로나19 방역 수칙 위반 업소 적발',
#  '얼굴로 결제, 올해 안에 됩니다',
#  '호반그룹, 협력사에 경영안정자금 60억 지원',
#  '몸에 좋고, 맛도 있네 기능성 앞세운 일반식품 속속 등장',
#  '[대전 청·정구역-Youth Politician Area] 5. 김선광 대전중구당협 청년위원장',
#  '옥천군, 정부예산 역대최대 171건 3595억원 획득 등 돋보여',
#  "영양군 안전한 여름휴가 '빈틈 없는 방역'",
#  '충북도, 화장품·뷰티산업 지역인재양성 강화',
#  '서령로타리클럽 2021-22년도 회장,임원 이,취임식',
#  "청주시, '안전·문화재생·협치' 민선 7기 3주년 성과 발표",
#  '[뉴스 분석] “샤넬백 1000만 원…오늘이 제일 싸요” 백화점 예약전쟁',
#  '대학 비대면 강의, 코로나 이후 28배 증가',
#  '[데스크시각] K-바이오랩 사업, 경남·부산 공동대응 필요 /김성룡',
#  "인천시 '현행 거리두기' 1주일 연장… 서울·경기도 기존 유지",
#  '[경인 WIDE] 코로나 장기화… 운동할 곳 없는 도민들',
#  '법무부 법사랑 인천 서구위원회, 검단노인복지관에 마스크 1만장 기부',
#  '[경기도 고위공직자 프로필] 김종석 양주시 부시장',
#  '경기도, 2021년 하반기 실·국장 및 부단체장 정기인사 단행',
#  '손 매무새 뽐내보소… 함평군, 평생교육 성과 공유회',
#  "광양시, 심신 치유 휴식공간 '스마트가든' 조성",
#  '김홍장 당진시장, 민선7기 후반기 회복과 도약이 목표',
#  '에너지절감 페인트 수출… 지구온도 낮추는데 기여하겠다 [로컬 포커스 강소기업 CEO를 만나다]',
#  '코스닥, 바이오 주춤하는 새… 게임·미디어 치고 올라왔다',
#  '‘김학의 출금 관여’ 기소된 이광철 사의…“검찰, 부당한 결정”',
#  '권익현 부안군수 “끝까지 단합된 힘으로 유능함 발휘 지역발전 이끌자”',
#  '강원 17개 시군 전면 등교…우려 속 일상 복귀',
#  '강원 15개 시군 모임 인원 제한 해제…우려 여전',
#  '부산, 거리두기 1단계로 완화…해수욕장에선 마스크 써야',
#  '경남 신규 확진 15명…백신 접종률 30.4%',
#  '천안 라이브카페 관련 누적 19명…지역 52명 신규 확진',
#  '경남 8개 시, 8명까지 허용 첫날…창원 도심 분위기는?',
#  '코로나19 신규 확진 대구 7명·경북 5명',
#  '대구·경북 사적 모임 최대 8인까지…‘기대 반 우려 반’',
#  '신규 확진자 이틀 연속 700명대…수도권 ‘새 거리두기’ 연기',
#  '신규 확진자 이틀 연속 700명대…수도권 ‘새 거리두기’ 연기',
#  '美 크루즈, 15개월 만에 운항 재개',
#  '[코로나19 국제뉴스] ‘유로 2020발’ 감염 확인…영국 일일 확진자 최대',
#  '과밀에 시달리는 특수학교…직업교육은 꿈도 못 꿔',
#  '울산, 어제 해외입국자 등 2명 신규 확진…누적 2,826명',
#  '수도권 ‘새 거리두기 적용’ 1주 연기…‘5인 이상 사적모임’ 계속 금지',
#  "'수신료 인상 추진' KBS 양승동 사장 코로나19 겪으며 공영방송 중요성 실감",
#  '“재택 끝, 사무실 가느니 그만 둘래”… 美 ‘대량사직’ 사태',
#  '권영세 안동시장, 청년위한 관광정책 편다',
#  "[열정! e경영인]여성 패션 전문몰 '더블유셀렉샵'",
#  "'8720원 vs 1만 800원'…최저임금 갈등 전북서도 팽팽",
#  '고양시 지방세 감면으로 재정손실…보전방안 건의',
#  '서양호 서울 중구청장, 취임 3주년 ‘현장행정’ 빛났다',
#  '경기도 대변인 국회 기본소득 공론화법 발의 환영',
#  '전영현 삼성SDI 사장 초격차 기술・품질・안전성 확보…창립 51주년 기념식',
#  '게이츠재단, 성평등 증진 2조4000억원 투입한다…빌 게이츠도 지지의사',
#  '국민지원금 대상 ‘건강보험료 활용’ 할 듯',
#  '카드사용액 2분기 100만원→3분기 153만원시 5만원 돌려받는다 [2차 추경]',
#  "코이카, 글로벌 서포터즈 'WeKO 3기' 모집",
#  "부산 16개 구·군 예산 중 최대 10%가 '묵은 돈'",
#  '순천시의회 생산적인 대안 제시·협력 지방자치 동반자 될 것',
#  '캠핑용품? 일단 예뻐야…감성캠핑 인기에 관련상품·굿즈 주목',
#  "'손님도 웃고, 주인도 웃고' 활기 찾은 식당...사회적거리두기 1단계 완화 강원도내 풍경",
#  '정읍시, 1일 민선 7기 취임 3주년 기념식',
#  '황교안, 대선 출마 비정상을 정상으로, 초일류국가 만들 것 [전문]',
#  '김기태 광주의료관광지원센터 신임 센터장 광주다운 매력 의료관광 기반조성 앞장',
#  '“3대 해양강국 가자!” ‘해양수산 지식인 1000인 모임’ 6일 출범',
#  "금성백조, '예미지 사랑나눔 봉사단' 국가유공자 노후주택 무료보수 실시",
#  '세븐틴 에스쿱스, 어깨 부상으로 미니 8집 활동 중단 안정 취하는 중',
#  '올여름 전력수요 역대 최고치 예상… 대란 우려',
#  "[단독] '수산업자' 김 회장, 농구대회로 포항시 속이려 했다",
#  '소급 뺀 손실보상법에…국힘·정의 날치기 한목소리',
#  '이광철 靑 민정비서관 사표…국정운영 부담 숙고',
#  "우민아트센터 2021 주제기획 '우리가 머물던 자리'",
#  "국회 본회의, '소상공인 손실보상법' 등 3건 안건 의결",
#  "김제시, 소상공인 시설개선사업으로 '활력'",
#  '전북 사회복지공동모금회, 완주군에 선풍기 197대 전달',
#  '서형호 30대 충북도농업기술원장 취임',
#  '3주년 맞은 민선7기 경기도정 성적표는?… 도민 74% 잘했다',
#  'AZ 접종 대상자 50세 이상으로 상향 조정, 50세 미만 2차 접종자는 화이자로',
#  '[동방인어] 코로나19 거리두기 어찌하오리까',
#  '은수미, 유흥·단란주점 484곳 자가검사키트 제공',
#  '\u200b주한 프랑스대사관 한국과 프랑스어권 국가 사이 교류 늘리자',
#  '오후 6시까지 서울 확진자 308명…사흘 연속 300명대',
#  "'中 심기 건드릴라' 숨죽인 홍콩, 축제는 없었다\xa0[中 공산당 100년]",
#  '“병원 나와 걷기앱 창업... 4년만에 매출 300억 찍었죠”',
#  '온·오프라인 혼합 수업 全교실 구축, 올해 안에 끝낸다',
#  '없던 오늘',
#  '도쿄 확진자 폭증…日총리 무관중 올림픽 있을 수 있어',
#  '[속보] 소급적용 빠진 코로나 손실보상법 국회 통과',
#  "'주52시간제' 손발 묶인 中企…현장서 일 안하는 사장 없어요",
#  '“아직은 불안”, 마스크 벗더라도 ‘2미터 거리 두기’',
#  '학령인구 급감, 과세 증가, 경쟁위주 평가... 대학 총장들 생존 위협',
#  '수도권 ‘거리두기 연장’… 클럽·파티룸 단체예약 올스톱',
#  "[6월 완성차 실적]기아, 수출은 '맑음'…내수는 반도체 영향 탓 '흐림'",
#  '남부발전, 불필요한 규제 없애고 中企 활력 돕는다',
#  '민주노총 토요일 전국노동자대회 강행...노동자 집회만 막나',
#  '文대통령, 한미연합사령관에 끼니와 생사고락 같이 하는 식구됐다',
#  '인천지역 제조업, 3·4분기 경기회복 기대감 큰 폭 상승',
#  '‘Thank 유 캠페인’, 한국유가공협회, 대한적십자사, 아트펌컴퍼니 공동주관 참여 협약 체결',
#  '文대통령, 이·취임 한미사령관에 한미동맹 더 굳건하게 발전',
#  "'두시만세' 김연자 밝힌 #어린 시절 #이석훈 축가 #무대비결(종합)",
#  '정은경 델타변이 수도권…거리두기 완화 시 폭발적 유행 우려',
#  '50대 26일부터 모더나·고3-교직원 19일부터 화이자 순차 접종',
#  '원어민 강사 발 감염 242명...산발적 집단감염 늘어',
#  "백신접종자 야외 운동·물놀이·관광때 '노마스크'...과태료 미부과",
#  '[종합] 거리두기 연장 필요성↑···수도권 ‘델타 변이’ 확산에 우려',
#  '보성군, 전국 최초로 백신 접종 완료자에 지역상품권 지급',
#  '미노벨, 웹소설 자유연재 플랫폼 베타 서비스 오픈',
#  '현대차, 6월 35만4409대 판매…전년비 14.4% 증가',
#  '52시간제에 반토막 난 월급…中企 근로자들 알바 뜁니다',
#  '도쿄 확진자 700명 돌파…스가 “무관중 올림픽 있을 수도”',
#  '[프로필] 이상균 수원시 예산재정과장 外',
#  '시진핑 “중화민족이 지배당하던 시대는 끝났다”',
#  '[2차 추경]1인당 64만원꼴 추경예산, 어디에 쓰나',
#  '홍남기-이주열 2년반만에 회동…재정·통화 ‘엇박자’ 지우나',
#  '코로나 스트레스 ‘부산항 힐링 야영장’에서 날려 보세요~',
#  '50대 국민 모더나 접종…AZ 권고연령 50세 이상으로 상향',
#  '이틀 연속 700명대…델타변이 급속 확산, 새 거리두기 반쪽 시행',
#  '[포토]이정훈 강동구청장, 민선 7기 취임 3주년 출근 직원들 격려로 시작',
#  '정은경 수도권서 델타변이까지...거리두기 완화시 폭발적 증가 우려',
#  '마일벌스, 여름맞이 아이스크림 공짜 이벤트 진행',
#  "'제15회 국가지속가능경영 컨퍼런스' 지속가능금융·제품책임 부문 우수기업은?",
#  '[대담한K] 기지개 켜는 마이스 산업…지역 경제 영향은?',
#  '사이버한국외대 한국어학부 ‘CUFS K-Culture 홍보 콘텐츠 공모전’ 시상',
#  '광주프린지페스티벌, 올해는 동네 곳곳 찾아간다',
#  '현대차·기아 `웃고`, 외자계 3사 `울고`',
#  "소부장 상장기업 매출 20% 늘었다…日 수출규제 '전화위복'",
#  '오스틴제약, 삼성제약과 제휴… 일반의약품 사업 진출',
#  '[문화톡톡] 사진으로 만나는 파리',
#  '주낙영 시장 모든 역량 집중해 미래 30년 착실히 준비 … 재선 도전해 마무리짓겠다',
#  '중랑구, 선별진료소 전자문진시스템 도입',
#  '[여기는 충주] 재건축 기대감에 가격 들썩…규제 피해 제천으로?',
#  "'기저효과' 현대차 6월판매 14.4% 증가…수출 덕에 웃었다",
#  '백신접종자 야외운동·물놀이·관광때 ‘노마스크’ 가능',
#  "[서울25]영등포구, 백신접종 완료자 음식값 10%할인·체육시설 할인 '혜택' 제공한다",
#  "[두둠칫 도서관] 시흥 소래고 '서경관'…경제교육 통해 지식 습득하고 사고 확장한다",
#  '국내 카니발, 해외 스포티지가 효자…기아 6월판매 20.2%↑',
#  '을숙도 예술공감 프로그램 지원하세요',
#  '규제 피한 고품격 하이엔드 단독주택 단지 ‘그랑빌 더 포레’ 이목 집중',
#  '정철동 LG이노텍 CEO 카메라용 독자 AI칩 개발...AI 적극 활용할 것',
#  '트럼프, ‘美 대통령 리더십 평가’서 44명 중 41위',
#  '[왓칭] 탑골공원 매춘부 할머니가 단골노인 만나다가 생긴 일',
#  '재난지원금 얼마 나오나…소득 1억↓ 4인가구 최대 140만원',
#  '쓰리디팩토리, MBC와 디지털휴먼 프로젝트…故김현식 홀로그램콘서트 제작 참여',
#  '국민 77% 여름휴가 활동 자제해야...코로나19 확산 우려',
#  '경기도장애인기능경기대회, 145명 선수 자웅 겨룬다',
#  '[서울포토] 손실보상 소급적용 촉구하는 심상정-류호정 의원',
#  "이재준 고양시장 시민 권리·미래 먹거리 찾아다닌 1년…철도망 확충은 '선물'",
#  '한국농수산식품유통공사, 농촌일손돕기 구슬땀',
#  '휴먼피부임상시험센터, 인하대병원에 발전기금 1000만원 전달',
#  '송영길 윤석열·최재형 인사검증 돌이켜 봐야...우리 무능 자백',
#  '(사)대한사랑·세계환단학회 ‘2021국제학술문화제’ 성황리 종료',
#  '3개월 소급 적용 ‘반쪽 손실보상법’ 본회의 통과',
#  '대형서점 ‘반디앤루니스’ 운영 서울문고, 기업회생 신청…6일 현장검증',
#  '백신 물량확보·도입추진에 1조5000억원…질병청, 추경 3조3585억원 편성',
#  '\u200b[종합] 文, 한미 연합사령관에 “끼니·생사고락 같이 하는 식구돼”',
#  '임광현 서울청장, 국세청 차장 임명…서울청장에는 임성빈 부산청장',
#  '충북문화재단 한국형 몽마르트르 언덕으로',
#  'AZ 백신 50대 이상만 접종한다…7월 대규모 백신 접종 예고, 수도권 확산세 잡는 게 관건',
#  '여름방학 과학과목 학년별 체크 포인트',
#  '일산 · 파주의 신흥 명문 고등학교 알아보기!',
#  '여름방학 수학 보충과 선행 계획은 어떻게?',
#  '해운대직업전문학교, 중1동 홀몸어르신 반찬 전달',
#  '50대 26일부터 모더나 백신 맞는다',
#  "휴가 가는 美…독립기념일 연휴 자동차 여행 '사상최대' 될듯",
#  '1주간 전국 학생 349명 확진...하루 평균 49.9명꼴',
#  '코로나19 백신 추가 도입에 1.5조 투입…질병청 추경 3조3,000억원 편성',
#  '文대통령, 에이브람스 한미연합사령관에 `보국 훈장 통일장` 수여',
#  '외국인 위한 셀프여행 가이드 영상 눈길…경북문화관광공사 제작·홍보',
#  '첫 해외출장에 코로나검사 8번…중동서 수출금융 51억弗 확보',
#  '‘모래폭풍 뚫어라’ 벤투호, ‘숙적’ 이란과 카타르행 승부',
#  '[레이더M] 신한대체운용, 골프장 매각으로 대박…IRR 70%',
#  "대기업은 주52시간 버텼지만…'체급 다른' 中企는 어쩌나",
#  "4.4조 투입해 조기 '집단면역' 달성...지역 경제에도 12조 지원",
#  '코로나19 백신 도입ㆍ접종에 국민 1인당 10만7000원...질병청 추경안 편성',
#  '<코로나종합>코로나19 신규 확진 4명 추가',
#  '(대구일보 지방선거 특별기획)2022년 지방선거 D-1년 대구·경북 누가 뛰나 (14) 김천시장',
#  '광주시 코로나 확진자 한달만에 두자릿수로… 7월 1일 15명 발생',
#  "한국형 몽마르트 언덕 '대성로 122 예술로'",
#  '[기고문] 원격운영으로 물류산업의 새로운 자동화시대를 열다',
#  '경남 1일 오후 확진자 4명 추가…거제 2명, 김해 ·함양 1명',
#  '교육부 차관 대학교 입시 담당자 우선접종 요청, 질병청장도 긍정적',
#  '노래방 종사자-손님 N차 감염… 대전 노래방 25곳으로 번졌다',
#  '임오경 정부 추경 적기에 통과돼야',
#  "코로나 뚫고 생산 '동화 베트남'… 중밀도섬유판(MDF) 시장 1위 굳힌다",
#  '설동호 교육감, 취임 3주년 성과·추진계획 발표',
#  '5500명 확진된 태국 “푸켓 관광객 격리 없이 입국” 첫날 표정은',
#  '대전 서구 유성구 노래방 관련 코로나19 확진자 5명 발생',
#  '황교안, 대선 출마선언 “문 정권 일탈 정상으로 돌려놓겠다”',
#  '일화, 제7회 KLPGA ‘맥콜·모나파크 오픈 with SBS Golf’ 개최',
#  "'6회 청주시민의 날' 첫 온라인 기념식",
#  '터키, 끝내 이스탄불 협약 탈퇴…여성인권 퇴보 우려',
#  '‘소급적용’ 빠진 손실보상법 통과됐다…국가교육위도 논란 끝 통과',
#  "'정책 엇박자' 의식했나...홍남기-이주열, 2년 7개월 만에 회동",
#  'KOTRA 하반기, 수출 호조세 이어간다',
#  '백신 맞으면 노마스크… 첫날 부러운 풍경 [포착]',
#  '50대 26일부터 모더나…고3·교직원 19일부터 화이자 접종',
#  'iH공사, 제7기 계약심의위원회 구성',
#  "청주시향 '나의 좋은 벗, 낭만에게' 추가 예매",
#  'AZ 백신 접종 60대 여성 숨져…유족 “후유증 앓아”',
#  '청주시, 6회 시민의 날 기념식 온라인 개최',
#  '무주사랑상품권 카드로 쓰면 5% 페이백',
#  '남원시, 점자·음성 민원안내시스템 도입',
#  '김성명 신임 완주부군수 취임',
#  '정읍시, 민선 7기 취임 3주년 기념식',
#  "10억 아파트 속속 출현…'3년 침체' 제주 집값 왜 오르나 봤더니…",
#  '[사설] N포세대 `이생망` 심리 파고든 샤넬의 얍삽한 商術',
#  "폭우에 시신 수백 구가 '둥둥'…인도 갠지스강에 무슨 일이?",
#  '비대면 무인 도서관 ‘스마트 도서관’',
#  '대학편입, 왜 1학년부터 준비해야 하는가?',
#  '“다시 저녁이 없는 삶”… 새내기 직장인들 ‘회식 부활’이 괴롭다',
#  '90분 후 결과 확인… 코로나 진단 마스크 개발',
#  '[무등의 시각] 절반만 남은 올해, 남은 기간도 무탈했으면',
#  "비수도권 오늘부터 '1단계'…기대 높은 만큼 우려도",
#  '인플레 헤지 역할 못한다…힘 못쓰는 금 왜?',
#  '[데스크라인] 소부장, 첨단산업 강국의 출발점',
#  '오늘부터 백신 해외접종자에 자가격리 면제서 발급',
#  '노숙인 하절기 안전사고 예방 나선 의정부시, 민원해소·보호활동 강화',
#  '21대 최용섭 서산세무서장 취임',
#  '대교협 회장 “대학 생존 위기…혁신지원사업비 2조 수준 확대해야”',
#  '광교신도시…랜드마크 상업시설 공급 소식에 상권 확대 기대',
#  '김정은 “적대세력의 中압박은 발악”… 시진핑에 축전 보내 밀착 과시',
#  '[ESC] ‘아웃도어 가구’로 뜨거운 여름 이겨 내볼까',
#  "암호화폐 부진한데 코스피는 '탄탄'…암호화폐 자금 증시로 옮겨올까",
#  '규제자유특구 출범 2년 만에 일자리 1,813개 창출',
#  '아산시 유지원 행정안전국장 명예로운 공직 마무리',
#  '마이크론 호실적에 커지는 기대감...삼전은 언제 올라요?',
#  '도쿄올림픽 축구 엔트리 22명 확대',
#  "누군 1년치 연봉 받는데…'코로나 지원금' 나는 얼마 받을까",
#  '상반기 수출 역대 최대…사상 첫 3000억달러 넘어(종합)',
#  '바디텍메드, 코로나19 중화항체 진단키트 수출허가 획득',
#  "오는 14일까지 '대덕e로움' 2주년 이벤트 벌여",
#  '소득하위 80% 1인당 25만원…저소득층에는 10만원씩 더 준다',
#  '국민의힘 與, 손실보상법 날치기 처리...입법독재',
#  '은성수 금융위원장 씨티은행 가능하다면 통매각 희망',
#  "나혼자 살기도 벅차…고용·부동산 참사에 '결혼·출산' 꺼린다 [신현보의 딥데이터]",
#  '\u200b창업 준비하나요? 은행이 상권분석 해줘요',
#  '132개 대학총장들 호소 저출산·코로나 위기…정부 지원 늘려야',
#  '대교협 총장 지원금 2조원 확대, 용도도 폐지해야',
#  '한국산업인력공단, 장기 중단된 산업잠수사 시험 재개',
#  '[프로필] 박정원 제21대 대구 서부소방서장',
#  '아시아나 무착륙 관광비행에서 한국 전통 문화 만나세요',
#  '광주 PC방서 확진자 접촉 중·고생 10일만에 감염…전수검사',
#  '‘코로나19 영업금지’ 유흥주점 재산세 감면 추진',
#  '현대차 3년만에 파업하나…임단협 결렬 7일 찬반투표',
#  '[하우스 인사이트] 주식 투자, 가치관 배제한 ‘객관적 분석’ 해야',
#  '[클릭 e종목]현대해상, 손해율 3년 새 최저점...목표주가 7% ↑',
#  '세계 코로나 사망자 400만명…미국, 사망자 62만명으로 최대 피해',
#  '美에는 답 없는 北, 中과 밀착…김정은, 공산당 100주년 축전',
#  '글로벌 바이오기업 써모피셔, 인천 송도에 바이오디자인센터 개소',
#  '자녀들 ‘등교 중지’·‘집콕’ 장기화…부모들, 정신건강 ‘빨간불’',
#  '헬피(HeLpy), 복용체크와 핑크노트 기능 업데이트...”사용자 편의성↑”',
#  '국산 백신 개발지원에 980억원…복지부, 추경 1조5502억원 편성',
#  "올여름 전력 예비율 최저 4.2%, 8년만에 '위기 경보' 가능성",
#  '공산당 100주년이지만 中은 여전히 비호감…美 호감도, 바이든 이후 급등',
#  '문금주 정책관, 전남도 행정부지사 취임',
#  'LG서 독립한 구본준의 LX그룹 출범…자산 8조, 재계 50위권',
#  '현대로템 ‘의왕 에코 플로깅 릴레이 챌린지’ 참여',
#  "성남시 '델타 변이' 3건 확인, 2주간 특별방역대책기간 지정…방역 총력전",
#  '포스트 코로나 대비 이달 신규 호텔 잇따라 문 연다',
#  "하반기 '10만전자' 가나…삼성전자, 2분기 실적 전망 봤더니",
#  '정부 지원금 부당 수급 부패 신고자 등 18명에 보상금 5억',
#  '제주서 AZ 접종 60대 여성 사망 신고 ...연관성 조사 중',
#  '격이 다른 명품 커뮤니티로 ‘워너비’ 주거지 만든다',
#  '[2차 추경] 소상공인 희망회복자금 3.25조 편성…손실보상 6000억',
#  '증평군의회 연풍희 의장 취임 1주년 맞아',
#  '감염병 위기 효과적 대응… 양평군, 코로나19 상시 선별진료소 개소',
#  '정세균 이재명 출마선언 나 따라해…기본소득 가성비 떨어져',
#  '빅터쇼룸, 상반기 수출 실적 달성...올해 300% 추가 성장 목표',
#  '이재명, 대통령 묘 대신 무명용사탑 참배 무명 민초가 나라 지켰다',
#  "주권 반환 24주년 맞은 홍콩, 경찰 1만 명 투입된 '조용한 하루'",
#  '“바이든 정부 장점은 개방성… 북한, 이번 기회마저 놓치면 안돼”',
#  'GNI개나리벽지, 바이러스와 세균 완벽 차단하는 ‘에비뉴’ 리뉴얼 출시해',
#  '신규 확진 762명...수도권에서만 607명 발생',
#  '담이랑 가족봉사단, 벽화그리기로 마을주민들에 웃음꽃 선물',
#  '한국공인회계사회, 7일 ‘ESG 전문가 양성 방안 심포지엄’ 개최',
#  "롯데면세점, 오사카 간사이공항점 '프레스티지 부티크'로 새단장",
#  '제노포커스 주가 14%↑...코로나19 진단 핵심원료 독점 계약 소식에 강세',
#  "국회, 오늘 본회의…'소상공인 손실보상법' 처리",
#  "한샘, '대한민국 동행세일' 동참…가구, 생활용품 등 할인",
#  '6월 수출 39.7%↑…상반기 첫 3000억 달러 돌파 \xa0',
#  '창립32주년 호반, 협력사에 경영안정자금 60억원 전달',
#  '도백 월급 기부로 시작된 나눔, 청년들에겐 ‘꿈’',
#  "옥천군, 특교세 11억 확보… 현안사업 '탄력'",
#  "'빚 안 내고' 33조 슈퍼 추경 편성… 소득 하위 80%에 10조 지급",
#  '저소득층 냉·난방비 220억원 쏜다...산업부, 추경 335억 투입',
#  '「바다가 보이는 부산항 힐링 야영장」 7월 재개장',
#  '청년 민심 붙잡을 1조8000억원…토익 응시료 등 70만원 지원',
#  '[2차 추경] 33조원, 역대 최대 수퍼 추경…1800만가구 1인당 25만원+α',
#  '캠코 온비드, 누적 거래금액 90조 돌파',
#  '2조 갚아도 올해 나랏빚 116조↑',
#  '동국제강, SK에코플랜트와 안심건축자재 사용 확대 위한 MOU 체결',
#  '日 롯데홀딩스 정기 주총서 드러난 롯데그룹의 실적 악화',
#  '비주류 흙수저에서 與 대권 유력주자까지…이재명이 걸어온 길',
#  '동대문구, 여름철 폭염특보 시 동주민센터와 연계 신속대응',
#  '민주 예비경선 TV토론…기본소득·개헌·조국 이슈 맞붙는다',
#  '윤석열, 순직 20대 소방관 애도…사랑하고 죄송하다',
#  '현대건설, 하반기 해외 실적 성장이 투자 포인트-이베스트',
#  '개편 코앞에 두고 강력한 경고음… 수도권 ‘5인 이상 모임 금지’ 일주일 연장',
#  '[사설]공급은 손놓고 ‘경고·부탁’으로 집값 잡으려는 無대책 정부',
#  "'경기국제보트쇼' 참가업체 모집…온라인 컨텐츠 강화한 '하이브리드 전시회'",
#  '코트라 “올해 수출 6000억 달러 돌파…하반기도 수출 호조”',
#  '美 “김정은 ‘중대 사건’ 발언 인지… 백신 외교 계속”',
#  "가족의 情 찾아…150개 재외공관서 '韓 격리면제' 접수",
#  '윤석열 보란듯… 이재명, 비대면 동영상 출마 선언',
#  '델타 변이 확산하는 美 “마스크 의무는 지방정부의 몫”',
#  '인천항만공사, 제2회 인천국제해양포럼 개최',
#  "이재명 '비대면' 출마 선언...희망민국 만들 것",
#  '황현식 LG유플러스 대표 “2025년까지 비통신 매출 비중 30%로 확대”',
#  '50대 어떤 백신 맞을까...7월 접종계획 오후 발표',
#  '신동원 농심그룹 회장 취임… 제품 개발·ESG·해외 확대',
#  '‘셰익스피어 전문가’가 돌아왔다, 거장의 마지막 비극으로',
#  '건설공제조합, 보증수수료 낮추고 보증·융자 한도는 올린다',
#  '서울시가 압류한 체납차량, 나도 사 볼까?',
#  '배민 방학도시락, “여름방학때 끼니걱정 없도록 아이들 도시락 선물”',
#  '[심층취재] 코로나 장기화속 “보육교사 대체인력난”…대안은?',
#  '속초시, ‘착한 임대인’ 재산세 감면',
#  '임대사업자 자진말소할랬더니 세입자 하는 말 동의비 주세요',
#  '캠코, 온비드 누적거래금액 90조원 돌파…회원 222만명 달해',
#  '전문가 “우리나라, ‘델타 변이’ 취약한 이유는…”',
#  '[속보] 신규확진 762명…지역발생 85.3%가 수도권',
#  '한샘 ‘대한민국 동행세일’ 동참…중기 판매 확대 지원',
#  '[2차 추경]역대 두 번째 슈퍼추경, 33兆 푼다..소득 하위 80% 1인당 25만원',
#  '軍, 오늘부터 1차 접종자 야외체육시설 노마스크 허용',
#  '연꽃 위 토도독… 빗방울 타고, 운치가 내린다',
#  '제46대 김용진 충주세무서장 취임',
#  '저소득층, 재난지원금에 소비플러스자금 10만원 더 받는다',
#  '충주문화원, 제47회 충청북도 학생백일장·사생대회 성료',
#  '시민들 “예약한 6명 모임 어쩌나”… 식당 “준비한 음식 다 버릴 판”',
#  'KT, 빅데이터로 ‘혼잡한 해수욕장’ 알려준다',
#  '영동군, 26대 이호 부군수 취임, 일등 자치단체 발걸음 동참',
#  "'네이버 주문' 이용 중소상공인에 6개월간 수수료 지원한다",
#  '속초시, 아동복지시설 10개소 안전점검',
#  '상반기 수출액 첫 3000억 달러 돌파… 15개 주력 품목 모두 늘었다',
#  '칸영화제 송강호는 심사위원으로, 이병헌은 시상자로 참석',
#  '연봉 1억 맞벌이도 지원금 주자는 여당...홍남기 다 고려했다',
#  "옥천군, 행정안전부 특별교부세 11억 원 확보 '지역 현안사업 탄력'",
#  '경상원-경기연구원, 소상공인 정책지원 협업',
#  '전문가 “사회적 거리두기 완화 유예, 2~3주 연장될 가능성”',
#  '경기도민 4명 중 3명 ‘잘했다’…3주년 정책 만족도 조사',
#  '코트라 올해 수출 역대 최대 6100억 달러 전망',
#  '사장님 가게에 네이버 주문 도입하고 6개월간 수수료 지원받으세요',
#  'LGU+, 2025년까지 비통신사업 매출 전체 30%로 확대',
#  '[마켓인사이트]장동헌 행정공제회 CIO, 전통적 자산배분 공식 이젠 안 통해...메인 떠오른 니치 자산에 주목해야',
#  '美 항공사 “곧 다시 난다” 비행기 사고 조종사 뽑고',
#  '[속보] 코로나19 신규 확진 762명…이틀 연속 700명대',
#  "'자가격리 해제' 세븐틴 오늘(1일) '엠카운트다운'으로 활동 재개",
#  "'1주일 더 4명만 모이세요' 수도권 새 거리두기 적용 미뤘다",
#  "오늘 이재명 출마선언...비대면 '유튜브' 출정식",
#  '영국 하루 확진 2만6천명으로 급증…매일 인원 발표 그만해야',
#  '상반기 1차 접종 30% 마무리...확산세 누르려면 속도 더 높여야',
#  '[포토뉴스]이재수 춘천시장 임시선별진료소 방문',
#  '[강원포럼]알펜시아 매각과 과제',
#  '[포토뉴스]주문진청년회의소 코로나19 생필품키트 지원',
#  "[속초]'착한 임대인' 재산세 감면",
#  "[춘천]'춘천인 음악회' 일정 연기",
#  "[민선7기 3년 강릉시]전통문화·청정환경에 첨단기술 접목 '강릉형 스마트도시' 구축",
#  '[뉴스분석] 北김정은, 대규모 문책인사...더 멀어진 남북·북미 대화',
#  '[경향의 눈] “억만장자는 지구를 떠나라”는 경고',
#  '“미군 난동 차단”… 해운대 방역수칙 위반 특별단속',
#  '[시온의 소리] ‘좋아요’를 누르십니까',
#  '“수소경제 등 9개 성장다리 사업 통해 울산의 재도약 이끌겠다”',
#  '다시 ‘무관중’ 기우는 도쿄 올림픽… 거리 성화봉송도 취소',
#  '“反中에 여야 없다”… 中견제에 똘똘 뭉친 美의회',
#  '코로나로 미뤄둔 결혼식 앞두고… 불길 뛰어든 20대 소방관 순직',
#  '수도권, 전파력 센 ‘델타 변이’ 비상등… 방역 완화 8시간前 연기',
#  '글로벌 엔터테인먼트 산업의 미래 조망',
#  '바이러스기초硏 초대 소장 최영기씨',
#  '[알립니다]코로나로 지친 일상, 수목원-정원에서 힐링해요',
#  '권영진 대구시장 “3대 숙원사업 해결” 가장 큰 성과',
#  "온라인으로, 지역사회로… '거리 두기' 속에서도 마음은 더 가까이",
#  '문화역서울284서 ‘공공디자인 가치’ 展',
#  '이강호 인천 남동구청장 “고유자원에 새 가치 더해…주민 자부심 높이기 주력”',
#  '[오늘의 설교] 후기 기독교 시대를 사는 지혜',
#  '한국농수산식품유통공사, 고객·임직원 180여명 참여 혁신토론회 개최',
#  '“하나님이 주신 중국어 달란트로 한·중 잇는 영적 다리 역할 하고 싶어”',
#  '조간 브리핑(7월 1일)',
#  "이재명 오늘 출마선언…현충원 찍고 '고향' TK 내려간다",
#  '[사설] 새 거리두기 첫날 반가움보다 우려 앞선다',
#  '[신선한 경제] 너도나도 복덕방…지난해 44만 명 창업',
#  '광진구, 청년 성공적인 취업 위한 자신감UP 캠프 개최',
#  '송영길, “맞벌이1억은 상위층아냐…재난지원금 받게 할 것',
#  "사람 구하러 뛰어들었다가…막내 소방관 '순직'",
#  '큐어백 백신 최종 예방효과 48%...승인 기준치 밑돌아',
#  '“인도 중산층 2억명 집에 한국가전 하나씩은 있어… 한국, 전기차 투자하라”',
#  "관악구 민방위교육장 '제2예방접종센터' 개소",
#  '부산항 해운항만산업 실태조사 시작',
#  '기초학력 부진·교육취약층 학생 집중 지원을',
#  '하반기 美 증시 더 오른다…이 3가지만 피하면 [김영필의 3분 월스트리트]',
#  'KTL-사천시 항공부품업계 살리기 맞손',
#  '거창군 코로나19 백신 접종기관 현장 점검',
#  '바르게살기의령군협 노인복지시설에 생필품',
#  '[미리보는 내년 6·1 지방선거] 대구 남구청장',
#  '델타변이 확산 美일리노이 “백신 맞았어도 외출땐 마스크 써야”',
#  '민선 7기 3주년 김문오 대구 달성군수 인터뷰…문화관광 등 성과 발판 새 달성시대 혼신',
#  '익산시, 7월부터 거리두기 개편안 적용',
#  "롯데百, 색조 화장품 매출 19%↑…'써머 뷰티 레시피' 행사 진행",
#  '완주군 직원들 딸기농가 찾아 지원활동',
#  '델타 변이 확산… 군은 거꾸로 방역지침 완화',
#  '“폐플라스틱 돈 된다”,,,재활용 기술 확보 뛰어든 화학업계',
#  '포스코 3Q에도 수익성 개선, 가격인상 하반기도 지속-SK證',
#  '포드, 반도체 공급난에 또 감산',
#  '[뉴스해설] 심상치 않은 코로나 재확산…방역 공든 탑 지켜내야',
#  '[코로나19] 신규확진 700명대 예상···수도권, 현행 거리두기 유지',
#  '독자투고>아동학대 예방신고, 참견이 아닌 관심입니다',
#  '대한상의 “3분기 경기 긍정적”…BSI 7년 만에 기준치 상회',
#  '北 리병철 등 코로나 사령탑 해임된 듯… 김정은 “국가비상방역 태만 중대사건”',
#  '이재명 오늘 ‘나홀로 출정식’… 안동 시작으로 영호남 훑는다',
#  '강서 ‘코로나 위기관리 공모대회’ 대상 수상',
#  "[YTN 실시간뉴스] 이재명, 오늘 출마 선언...與 9명 '출사표'",
#  '[하반기 이렇게 달라집니다] 투명페트병 분리배출제 전국 확대… 자치경찰제 전면 시행',
#  '‘트롯 걸그룹’ 미스티 “이제까지 이런 그룹이 있었을까요?” [M+인터뷰]',
#  '국제유가, OPEC+ 결정 앞두고 상승…WTI 0.7%↑ [인더머니]',
#  '[사진] 헌법기관장들과 인사하는 문 대통령',
#  '[사진] 코로나 검사 기다리는 대구 시민들',
#  '가라테 박희준, 종주국 하늘에 태극기 올린다',
#  '미용실 불 끄다 스프레이통 폭발…결혼식 앞둔 20대 소방관 순직',
#  '60~74세, 2차 접종까지 두 달 공백 “화이자·모더나 교차접종 서둘러야”',
#  '[2021 한국서비스품질지수(KS-SQI)] 코로나 속 3년 연속 사상 최대 실적',
#  '[분양 포커스] 2100만원대 한강뷰·숲세권 … 부분철거 시작, 착공까지 순항 예고',
#  '미국 집값도 미쳤다, 34년 만에 최대 폭등',
#  '[2021 한국서비스품질지수(KS-SQI)] 보안·건물관리 등 다양한 솔루션',
#  '[2021 한국서비스품질지수(KS-SQI)] 메타버스 시대, 통신 품질 확보해야',
#  '[시조가 있는 아침] (78) 삶이란',
#  '킥라니 범칙금 한달 8400만원인데…여전히 면허증 없이 된다?',
#  '반도체·차·조선·철강 등 하반기 실적도 ‘쾌청’... 원자재값·물류비는 ‘변수’',
#  '“이 시국에 웬 한중해저터널 양승조 공약에 네티즌 불만 폭발',
#  "‘함께 일하자' 줄 서던 ‘이직의 여왕'이 한 뜻밖의 선택",
#  '‘사적 모임’ 완화돼도 방역 긴장도는 더 높여야',
#  '반구대암각화세계유산추진단 신설',
#  '“촛불집회·코로나 방역에 전 세계가 경탄”',
#  '오피스넥스, 특수상권 가맹점엔 임차료 50% 지원',
#  '광공업·서비스업은 줄었는데… 공공행정만 백신발 7년來 최고',
#  '시진핑 오늘 천안문 연설… 마오처럼 망루 올라 ‘중국몽’ 외치나',
#  '또봉이통닭, 지역별 시식회 등 점주와 상생 노력',
#  '[돈되는 분양] 현대 테라타워 구리갈매, 프리미엄 브랜드·우수한 입지·탁월한 상품성…3박자 갖춘 복합비즈니스센터',
#  '“8월까지 고용보험기금 재정건전화 방안 마련”',
#  '김정은 ‘방역 태만’ 책임 이유 정치국 상무위원 해임 조치',
#  '“산재전문 공공병원 설립·울산외곽순환도로 개설 큰 성과”',
#  "대중음악 공연 '기지개'...확진자 증가에 우려도 커져",
#  "장이 달라졌다더니…'빅7' 시총 10조달러, 기술주 더 달리나?",
#  "마블 신작 '블랙 위도우', 2년의 기다림에 대한 보상은 충분하다",
#  '[사설] 북한 중대 사건으로 상무위원 숙청, 예의 주시해야',
#  "'여의도 신인' 윤석열·최재형의 공통점은?... '친구 정치'",
#  '코스피 최고가 달리자, 곱버스 탄 개미들…어라? 또 오르네',
#  '[짜오! 베트남]\xa0푸꾸옥 열리면 투자 급증할 것 코로나 시대 베트남 부동산의 명암',
#  '[짜오! 베트남]\xa0세계에서 공장임대 비용 가장 저렴한 곳은 하노이, 이유는?',
#  '[속보] 어제 코로나19 신규확진 762명… 이틀 연속 700명대 확진',
#  '노원구, 9월 말까지 ‘무더위쉼터’ 연다',
#  '상반기 수출 사상 첫 3000억불 돌파…6월 수출만 40% 급증',
#  '제2회 다이와 패션쇼 2021, 피싱웨어의 고급화·대중화 선도...낚시도 예뻐야 낚시다',
#  '버핏-멍거 팬데믹 영향 불균형…車딜러는 오히려 큰 수익',
#  '현대차, 상용차 고객에 매연저감장치 클리닝 비용 50% 지원',
#  '울산 울주군의회, 추경안 부결 후폭풍 거세',
#  '델타 변이, 올 게 왔다… 수도권 6개 어학원 감염자서 확인',
#  '원자잿값·물류비 상승·인플레이션 우려',
#  '울산 산업생산 회복 더디고 소비자는 지갑 닫아',
#  '한국수력원자력(주) 새울원자력본부, 취약층 250가구에 서생멸치 선물',
#  "횡성 4대 지역축제 '축소 개최' 가닥",
#  'S-OIL, 위기가정 긴급지원금 2천만원 기탁',
#  '\u200b\u200b하반기 국내 증시, 다시 대형·성장주 시대 온다',
#  "평창군건강위 주민 건강증진·코로나 방역봉사 '앞장'",
#  '현대자동차 2021년 임단협 결렬…파업절차 돌입',
#  '용문~홍천철도 4차 국가철도망 확정 등 홍천 성장기반 마련',
#  '[사설] 대구시의 ‘방역 무능’ 또다시 노출한 이마트 월배점 사태',
#  '정상혁 보은군수 민선 7기 3주년 및 재임 11주년 기념식',
#  '음성 금왕농협, 농촌사랑기금 500만 원 전달',
#  '보은군 개인지방소득 환급금 조기지급 완료',
#  '[세계와우리] 북한 비핵화 협상을 재개하려면',
#  "충주시, 민선 7기 3주년 시정성과 발표…'더 가까이, 충주' 슬로건 확정",
#  '[커버스토리] 호텔·렌터카·레저까지…손품 팔면알뜰 휴가 잡는다',
#  '곡성군 AI로봇 노인건강관리... 방문보건사업 활용',
#  '[한경에세이] 좌판 노인의 가득 찬 바구니',
#  '강원 6개 시군 14명 코로나19 신규 확진',
#  '도쿄올림픽 축구 참가 선수 22명으로 확대... 4명에게 기회가',
#  '국민 80%에 1인당 25만원 재난지원금',
#  '안성시 일대 유흥주점서 불법취업 외국인 접객원 12명 적발',
#  "정부 하위 80% vs 與 확대…재난지원금 기준은 아직도 '깜깜'",
#  "'코로나 사망자 40만명' 인도 대법원 유족 보상금 지급하라",
#  '상반기 수출 사상 첫 3000억弗 돌파…연간 수출도 최고치 전망',
#  '[새얼굴] 김윤호 의정부소방서장 外',
#  '휴가 앞두고 심상치 않다…내일 확진자 800명 안팎 예상…오후 9시까지 716명',
#  '장휘국 광주시교육감 “코로나로 위축된 학교 교육력 회복하겠다”',
#  '국가철도공단, 20개 협력사와 적정대가 산정 등 상생협력 간담회',
#  "아이디어 실현될 수 있도록…의왕시, 창업지원주택 '청년e-Room' 아이디어 공모전 개최",
#  '동작구, 집합금지·영업제한 업종 폐업 소상공인 50만원 지원',
#  '글로벌생명나눔, 탄자니아에 1차 의료물품 선적',
#  "김승연 회장, '40년 친분' 퓰너 美 헤리티지재단 회장과 만찬",
#  "서산시의회 이연희 의장 취임 1주년 '시민이 주인인 의정'이어갈 것",
#  '우리의 일상이 다시 힘차게 시작됩니다 서산시, 사회적 거리두기 개편 담화문 발표',
#  '왜목마을, 난지섬 해수욕장 7월 10일 개장',
#  '고대면 새마을부녀협의회, 사랑담은 열무김치 봉사 펼쳐',
#  '가세로 태안군수, 4차년도 맞아 군정성과 및 과제 밝혀!',
#  "예산군 추사고택 일대, 초록빛 싱그러움이 '한 가득!'",
#  '영동군 제26대 이호 신임 부군수 취임',
#  '美 마이크론의 자신감…업계 최초 4세대 D램·176단 낸드가 주력 될 것',
#  '5년 뒤엔 국산 항암백신… `K-mRNA 혁신` 시작됐다',
#  'MZ세대가 원하는 정치',
#  '대구 호텔업계 코로나 직격탄에다 각종 루머까지 사면초가',
#  '전북농협, 5일 라이브 커머스로 수박 판매 방송',
#  '전주시 “탄소중립·신성장산업” 100년 미래 열어간다',
#  '노인회 전북연합회 ‘틀니 세정제·부착재 지원사업’ 물품 전달',
#  '국제로타리 3670지구 제51대 박종완 총재 취임식',
#  '대입 수험생 등 우선 접종…50대는 12일부터 사전예약',
#  '조지영 신임 전주완산의용소방대 연합회장 취임',
#  '핵심품목 일본 의존도 낮아지고 ‘소부장’ 강해졌다…일본 수출규제가 부른 ‘나비효과’',
#  '[여기는 전남] 지방의회 부활 30년 기념행사 이어져 외',
#  "이제 충청권 광역철도 '사타'에 집중하자",
#  '백신 맞은 외국인 푸껫 갈 수 있다…15개월 만에 재개방',
#  "'취임 3주년' 강은희 대구시교육감, 재선 도전 시사 장기 과제 수행 위해",
#  '하루 만에 100만원 뛰었다…샤넬백 1,000만원 시대',
#  '10월께 조정場 가능성…우량주 싸게 담을 기회',
#  '과학에도 비평이 필요한가',
#  '소득 하위 80%에 재난지원금…형평성 논란에 벌써 “확대” 주장',
#  '연일 700명대 확진에 백신 접종도 주춤…‘7월 고비’에 선 방역',
#  '132개대 총장들 위기의 대학…재정 지원 대폭 늘려야',
#  '올여름 전력수요 역대 최대 전망…8년 만에 수급경보 발령될 수도',
#  '스물다섯 생일상 받은 코스닥, 21년만에 최고점 ‘자축’',
#  '50대 26일부터 모더나 접종…50살 미만은 이제 AZ 안맞아',
#  '[황출새]이재갑거리두기 완화, 유예기간 일주일로 끝내기 어려울 듯',
#  '[ET] 5차 재난지원금, 1인당 25만 원 준다…나도 받나?',
#  "첩보작전 벌이듯…유흥주점의 치밀한 'CCTV 입장법'",
#  "주삿바늘 없이 접종…첫 'DNA 백신' 인도서 긴급사용 신청",
#  "경기아트센터, 백신 접종자에 '30% 할인' 혜택",
#  '[김영윤 칼럼] 北美대화 문턱 낮추기, 미국 움직일 외교를',
#  "'33조' 2차 추경 의결…1인당 25만 원 지원",
#  "'혈전 논란' AZ백신 50세 이상에만 접종… 50세 미만 2차 접종은 화이자",
#  '유탑부티크호텔&레지던스, 호캉스 상품 출시',
#  '롯데아울렛 광주월드컵점, 고급화 전략 ‘박차’',
#  '“전남 사회적기업 우수 제품 꾸러미 이용하세요”',
#  '세종대 PB MBA 학생 모집…투자자산운용사 등 자격증 취득',
#  '이승옥 강진군수 “군민 행복 증진·지역경제 활성화 집중”',
#  '한전기술, 김천 자두축제로 ‘대한민국 동행세일’ 동참',
#  "뷔페 식재료 다 사놨는데…수도권 거리두기 연장에 호텔 '날벼락'",
#  '안도걸 기재차관 “국채 조기상환에 올 3.7兆 쓸 것”',
#  '정은경 수도권 델타변이 확산…거리두기 완화시 폭발적 유행 우려',
#  "이재명, 윤석열과 '확' 달랐다... ①실적 부각 ②단출한 비대면 출마선언",
#  '오산시, 죽미령 전투 71주년 전몰장병 추도식 개최',
#  '주 52시간제 노사 ‘온도차’…“초반 혼선 불가피”',
#  "'OO님, 음성입니다'…다른 검사자 결과 보낸 남구보건소",
#  '6개 시군, 14명 신규 확진…강원 누적 3,583명',
#  '김승수 전주시장 “내년에 지방선거 출마 않겠다”',
#  '이틀 연속 700명↑…전남 ‘수도권 발’ 확산',
#  '서동용 ‘장애인 특수교육법’ 개정안 발의',
#  '7월 2일 인사',
#  'AZ접종 50세 이상으로 상향… 당국, 7월 접종 세부계획 발표',
#  '[코로나 19] 대전 30일 밤사이 신규 확진자 5명 추가 발생',
#  '[충북&오늘] 충주 지역화폐, 연말까지 10% 할인 판매',
#  '다시 뜨는 철강산업...채용문도 활짝',
#  "[뉴있저] 오늘부터 비수도권 '새 거리두기'...감염 확산 우려는?",
#  '[2차 추경]소상공인 5차 재난지원금 최대 900만원…일반업종은 제외',
#  '국세청 차장 임광현, 서울청장 임성빈',
#  '소득 하위 80%에 1인당 25만원 지원금',
#  '“울산시, 윈드서핑, 딩기요트, 카누 무료체험 하세요”',
#  '울산시민아카데미 개강',
#  '중앙농협, 스쿨뱅킹 장학금 81명에 1,620만원 전달',
#  '해운 물류 플랫폼 개발, 통합항해시스템 국산화 본격 추진',
#  '“신세계, 울산시민에 사과하고 백화점 입점 이행하라”',
#  '“취업문 확장 등 지역 청년 유출 방지 방안 강구하겠다”',
#  '대한민국팔각회 울산지구, 생명나눔 헌혈 행사 실시',
#  '농협중앙회 울산본부, 올해 2분기 범농협 사회공헌상 수상',
#  'WHO 유럽 확진자 다시 증가...향후 새로운 유행 가능성 경고',
#  '[나이트포커스] 이재명 흙수저 비주류...대선 출마 선언',
#  '마오처럼 망루 오른 시진핑 “위대한 중국” 포효…서방 국가엔 경고도',
#  '‘거리두기 완화’…대리요금, 광주 줄고 전남 올랐다',
#  '[OBS 뉴스오늘1] 희망민국 만들 것…이재명, 비대면 출마 선언',
#  '독도사랑광주포럼 “일본은 올림픽 지도에서 독도 표기 삭제하라”',
#  '지리산 자락 힐링 명소 즐비한 남원으로 오세요',
#  '문금주 전남도 신임 행정부지사 2일 취임',
#  '美 연구진 남성이 코로나에 취약...여성보다 중증 위험 높아',
#  '전세계 온실가스 줄었는데... 한국 CO₂ 농도는 역대 최대치, 왜?',
#  '전남농협, 사랑의 생명나눔 헌혈 캠페인',
#  '수도권은 울상, 비수도권은 웃음...거리두기 단계에 희비교차',
#  '인천시, 노래방 종사자 코로나19 진단검사 행정명령',
#  '고3·교직원은 19일부터 ‘화이자’…50대는 26일부터 ‘모더나’ 접종',
#  '경남도, 여름 휴가철 대비 숙박업소 2900여개 점검 나서',
#  "한·중 수교 30주년...정부, '한한령'·'반중정서' 해소에 사활",
#  '네팔교회 목회자 코로나로 수백명 사망, 교회마다 리더십 진공 상태',
#  '권영진 대구시장 3선 가도 이상 없나',
#  '대한항공 “LA행 화물기에 중소기업 전용공간 운영”',
#  '전통 연희와 서양 음악의 조화로 꾸미는 놀이판…뮤지컬 ‘판’ 27일 개막',
#  '김성기 가평군수, 민선7기 3주년 기념 백신접종센터 봉사 활동',
#  'K-water 주암댐지사, 노인일자리사업 55명 창출',
#  '‘모가디슈’ 류승완 감독, “기밀 해제된 미국 대사관 자료를 바탕으로 소말리아 내전 상황 재현”',
#  '백신 접종자 야외 노마스크…마음은 굴뚝 같지만, 아직은 불안',
#  "청주시 '유흥시설·식당·카페 특별점검' 강화",
#  '온·오프라인으로 여는 2022 경북 진학 박람회',
#  '인도네시아 족자카르타주에서 새마을세계화사업 펼친다.',
#  '정승재 교수 소비자의 선택은 언제나 변한다…철저한 시장분석·창의적 마케팅으로 승부',
#  '초등, 중등 의치약 전문 빅파이브(Big5) 학원 목동에 개원',
#  '이달부터 예약자 수 관계없이 백신 개봉…잔여백신은 네이버·카카오로',
#  'AZ백신 50세 이상에만 접종...50세 미만 2차 접종은 화이자로',
#  '경영복귀 김승연 회장 공식 대외활동 나서',
#  '진영 “지성 먼저 캐스팅, 안 할 이유 없었다”(악마판사)',
#  '은성수 금리상승기 부담, 은행과 차주의 분담 검토해달라',
#  '김영식 의원, 과학기술강국포럼 발족',
#  '해남군,\xa0코로나 위기관리 단체장 리더십 분야\xa0대상',
#  '감정가 4.7억 짜리 남양주 땅이 40억에 낙찰…토지·오피스텔도 경매 열풍 [부동산360]',
#  'AZ 접종 제한 연령, 30세→50세로 상향… 희귀 혈전증 위험 높아',
#  '델타 변이 확산, 경제활동 재개 늦추나',
#  "화이자 '보라' 모더나 '빨강'…백신 고유색깔로 오접종 막는다",
#  'KT, 빅데이터 이용해 ‘혼잡한 해수욕장’ 알려준다',
#  '‘유로2020발’ 감염 현실화된 영국, 3천만명 백신 추가접종 계획 착수',
#  '경북 해수욕장, 9일부터 개장해 내달 22일까지 운영',
#  '씨젠, 델타 포함 6개 코로나19 변이 찾아내는 진단시약 출시',
#  '북한, 김정은·여정 남매통치 강화, 간부들 물갈이(종합)',
#  '오스틴제약, 일반의약품 사업 강화…삼성제약 11개 품목 독점 판매',
#  '김석준 부산교육감 “부산교육을 미래교육으로 대전환”',
#  '김총리, 민주노총에 코로나 상황 엄중... 불법집회 자제하라',
#  "중기중앙회-산업인력공단 '능력중심 인사체계 확산' MOU",
#  'J형 나와라 5일 최재형 지지선언…국민 무거운 짐 질 사람',
#  '대한항공, 중소기업 수출 항공운송으로 지원',
#  '영우디에스피 “건양대와 손잡고 의료용 돌봄 로봇 시장 진출”',
#  'AZ 1차 맞은 50세 미만 161만명, 2차 화이자 교차접종하게 된다',
#  '델타 변이에 초토화됐다 시드니 파티장 30명 중 24명 감염…백신 접종자는 피했다',
#  '[단독]공정위, 김범석 쿠팡 전 의장 `동일인` 지정방법 찾는다…금주내 연구용역',
#  '美 마이크론 영업이익 전년比 2배로…메모리반도체 기대감↑',
#  '빕스·계절밥상·남산타워, 백신 접종자에게 할인',
#  '대전, 8명 사적 모임 허용...단체 손님 예상보다 적어',
#  '임실N치즈 공격적 마케팅에 매출 ‘쑥쑥’',
#  '[속보] 50세 미만 AZ 접종자, 모두 화이자로 2차 교차 접종받는다',
#  '[속보] 고3·고교 교직원 64만명, 19일부터 화이자 백신 접종',
#  '[속보] 55~59세 12일, 50~54세 19일부터 백신 사전예약',
#  '50대 742만명, 26일부터 모더나 맞는다… 고3·교직원·입대 장병 등은 화이자',
#  '[속보] 부속의원 보유 사업장 종사자 39만명, 이달 말부터 모더나 접종',
#  '트럼프, 美대통령 평가 44명 중 41등… 꼴찌는 누구?',
#  '‘델타 변이 대확산’ 위기… 트래블 버블·2학기 전면등교 혼란',
#  '[팩트체크] 1회 이상 접종자, 한적한 실외서만 마스크 벗을 수 있어',
#  '지성 “오랜만에 안방극장, 조커 같은 판사 역할”(악마판사)',
#  '거제시 예비 부모 육아 상식 퀴즈대회',
#  "'중대재해법 전담' 고용부 산안본부장에 권기섭",
#  '창원시, 7월 정례조회 열어 전 직원 시정공유',
#  "박형준표 민·관 협치 정책 프로세스, '비상경제대책회의' 체계 안착",
#  '부산시, 지역 성장을 위한 지산학 협력의 새로운 도약',
#  '김민정 “‘악마판사’서 맡은 역할, 킬힐처럼 아찔한 매력 있다”',
#  '노원구 어르신 폭염특보 땐 호캉스 한다?',
#  "'취임 3주년' 박승원 광명시장, 시민 75.1% 잘하고 있다 긍정평가",
#  '창원시, 의로운 영웅들에게 감사의 마음 전해',
#  "장원건축사무소, 강진 작천 '까치내문화나눔터'에 TV 기증",
#  '1인 25만원+소상공인 최대 900만원…33조 2차 추경안 의결',
#  '대전, 노래방 매개 연쇄 감염 확산세… 관련 누적 확진자 28명',
#  "7월, SK스토아가 7777개 행운을 쏜다…'럭키스토아' 프로모션",
#  "'소주 원조' 진로, 에피어워드 코리아 6개 부문 수상",
#  "실화 소재X극적 취재로 완성된 '모가디슈', 韓영화 구원투수 될까 (종합)",
#  '충남 33개 지정 해수욕장 오는 3일 개장',
#  "예산군, '2021 코로나 위기관리 대상 공모대회' 최우수상 수상",
#  "예산군 추사고택 일대, 초록빛 싱그러움 '한가득'",
#  '대교협 “코로나19로 대학 생존 위협…재정 지원 확대해야”',
#  '이달말 ‘전력수급 비상’ 발령 가능성… 탈원전發 블랙아웃 우려',
#  '담이랑 가족봉사단, 벽화그리기로 마을주민들에 웃음꽃 선물',
#  "영동와인터널 오랜 기다림 끝 '문 활짝'",
#  '영동군, 이호 부군수 취임',
#  '코로나 해소전까지 임대료 연체 가능?…정책發 갈등 확산',
#  "서울시, '하수도관 접합기술 경진대회' 하수도 품질 고도화 기술 발굴",
#  '캐롯손보·티맵, 코로나19 백신 부작용 보험 3만명 무상제공 이벤트',
#  '오프라인 그루밍도 처벌규정 마련해야',
#  '조금 느려도 제대로 가는 영어 교육, 아이보람이 함께 갑니다',
#  '기업지배구조 소폭 개선',
#  '중진공, 해외거점 전략회의',
#  '보건복지부, 추경 1조5502억···“백신 개발 임상3상 980억 투입”',
#  '김부겸 총리 코로나 확진 엄중한 상황에 민노총 집회 자제해야',
#  '불리한 내신등급으로 상위권 대학에 합격할 수 있는 기회',
#  '성남시, 14일까지 2주간 특별방역대책기간 운영',
#  "'확진자 응시제한' 임용고시생 국가배상 소송 첫 재판...적법성 공방",
#  '‘스마트 건강관리’ 시스템으로 취약층 돌본다 … 고신대복음병원, ‘안심관리’ 개발사업 선정',
#  '에듀앤플레이, 2021 비대면 스타트업 육성사업 선정',
#  '태영호 김정은 노발대발, 군량미 허위보고 때문일 것',
#  '김재종 옥천군수, 주민과 소통 행보 나서',
#  '이세열 서울시의원, ´마포동 불당제´ 참석',
#  '민선7기 3주년 맞은 류한우 단양군수, 현장중심 소통행보',
#  '평창서 코로나19 확진자 1명 추가 발생…누적 187명',
#  '보은군, 개인지방소득환급금 조기지급',
#  '음성군 직장·공장새마을운동협의회, 요양시설 방역활동 실시',
#  '제천시 보건소, 이열치열 더위탈출 챌린지 사업 추진',
#  '충주 풍물시장상인회, 어려운 이웃을 위한 나눔 활동',
#  '의료기기 특허출원 증가율, 평균 출원율 보다 3.6배 높아',
#  '푸틴, 러시아 백신 스푸트니크V 접종...관련주 이트론, 이아이디, 이화전기, 이수앱지스, 휴온스글로벌 등은?',
#  '음성 맹동산단입주업체협의회, 장학기금 기탁',
#  '김 총리, 민주노총에 경고 방역 엄중한 상황, 대규모 집회 자제해달라',
#  '김부겸 “코로나19 확산 기로…민주노총, 대규모 집회 자제해달라”',
#  '씨젠, 美 바이오라드와 손잡고 미국 시장 진출 본격화',
#  '호실적에 중간배당까지…금융지주 살맛나네[이슈+]',
#  '中 매체 “공산당, 인민 이끌고 포위망 뚫고 승리” 자화자찬…홍콩·대만은 ‘싸늘’',
#  '최고 스마트폰은 갤럭시S21 울트라…아이폰 제쳤다',
#  '손주 둔 58세 식스팩 할배…세미 세이기너의 ‘시간은 거꾸로 간다’',
#  '금호석유 현재 주가 저평가…목표주가 33만원 [SK증권]',
#  "고흥에서 '자연의자리 미술의자리'",
#  '의료기기 특허출원 증가율, 전체 특허출원 평균보다 3.6배 높아',
#  '서천군, 강력한 재정 집행으로 지역경제 회복 앞장',
#  '큐어백 효과 48%로 최종 분석',
#  'NH농협생명, 모바일 청약 시스템 오픈',
#  '코로나, 불황…고달픈 제주 청년들에 심리 지원 서비스',
#  '예산 임성중학교, 재생에너지 전문가 체험 프로그램 실시',
#  '[동정] 7월 2일 천안시 읍면동장',
#  '케어랩스 굿닥, 물적분할 1주년… “사용 건수 월 122% 고속 성장세”',
#  '[NNA] 말레이시아 정부, 라부안 입경 오늘부터 규제강화',
#  '111년 만의 폭염 왔던 2018년 이후 전력 수요 최고치',
#  '충주문화원 47회 충북학생 백일장·사생대회 성료',
#  '인천시, 노래연습장 종사자 코로나19 진단검사 행정명령',
#  "군, 1일부터 백신 접종자 야외체육시설 '노마스크’",
#  '편의점은 담배 전시장… “전자담배 광고, VR게임 같다”',
#  '포스트 코로나시대 ‘과학기술인’ 육성방안 찾는다',
#  "S&P, 이마트 '부정적 관찰대상' 지정…이베이코리아 인수 부담 [마켓인사이트]",
#  '건설공제조합, 보증수수료 낮추고 이용한도 늘리고',
#  "한화투자증권, 집에서 참여하는 비대면 사회공헌 '라폴' 성료",
#  '코로나 딛고 역대 최대 상반기 수출…사상 첫 3000억불 돌파',
#  '美 캘리포니아 작년 아시아계 대상 증오 범죄 두 배로 늘어',
#  '유로 2020발 감염 비상…“런던 원정팬 약 2000명 확진”',
#  '오늘 춘천 2명 신규 확진…더존비즈온 진단검사 음성',
#  '‘본업 깡패’ LGU+, ‘부업’ 늘린다…비통신 매출 30%까지 높이기로',
#  '[최명성의 바닥탈출] 코로나19 스푸트니크V 관련주 <이화전기>',
#  '금융지주 중간배당 스타트 준비하는 하나금융…얼마나 늘릴까',
#  '목재 가격 40% 폭락…그래도 코로나 이전의 두 배',
#  "이천 마장초, 찾아오는 예술 여행 '너와 나의 더 케미스트리' 공연 관람",
#  '의왕시, 민선7기 공약사업 6월말 기준 이행률 93%',
#  '[포토] 김민정, 완벽한 비율로',
#  '[포토] 지성, 악을 처단하는 악으로',
#  "[포토] '악마판사', 통쾌함 전해주며",
#  '[포토] 조인성, 완벽한 비율로',
#  '[포토] 모가디슈, 기대되는 캐스팅',
#  "[포토] 박경혜, '모가디슈' 기대하세요",
#  '[포토] 김재화, 시선 잡는 연기로',
#  '결혼식 넉 달 앞뒀는데…화염 뚫고 구조 나섰다 순직',
#  '신동원 농심 회장 취임 “혁신 통해 미래 성장”',
#  '‘마오’ 위에 시진핑 “중화민족 부흥” 결속 다지며 서방엔 ‘경고’',
#  '“식재료 잔뜩 쌓아놨는데…” 예약 줄취소',
#  "백신 접종자 '실외 노마스크' 허용 첫날 아직은...",
#  '오는 26일부터 55세 이상 모더나 접종...고3 수험생은 19일 1차 접종',
#  '오는 26일부터 55세 이상 모더나 접종...고3 수험생은 19일 1차 접종',
#  "6월 수출 '최고 기록'...상반기 수출 3천억 달러 첫 돌파",
#  '결혼 앞둔 20대 막내 소방관 인명구조 중 순직',
#  '김해시, 민선7기 4년차 흔들림 없이 간다',
#  '부원동지역사회보장협의체, ‘취약계층 어르신 힐링 문화체험’ 추진',
#  '인제대 GTEP사업단 코로나19속에서도 무역역량 강화 UP!',
#  '변광용 거제시장, 민선7기 3주년 기자 간담회 열어',
#  '김철훈 영도구청장, 민선7기 3주년.. 현장중심 소통행정 나서',
#  '금정구 민선7기 4년차 ‘소통행정’ 결의',
#  '거제3동 청년회, 창립 45주년 기념 소상공인에게 성금 기부',
#  '연산8동 새마을문고회, 천연비누 나눔 행사 개최',
#  "대연3동 행정복지센터, '책이랑 보드랑' 강좌 개최",
#  '부산진구, 2021년 동천은행나무길 아트프리마켓 개장',
#  '거제시, 대기업 건설사 초청 투자유치설명회 개최',
#  '김해시, 여름철 물놀이지역 안전사고 예방대책 추진',
#  '드론 활용하고 야간쉼터 만들고… 복지 차원 폭염 대책 세운다',
#  '팬데믹이 바꾼 상권 지도...안정성이 답! 주거 상권 ‘재조명’',
#  '시민과 경찰의 인권이 함께 존중 받아야 할 때',
#  '“7·3 전국노동자대회, 노동자 절박한 요구”…강행 입장 재확인',
#  '진단키트 7억개…삼바보다 7배 더 번 SD바이오센서',
#  '1인당 25만 원 지급…저소득층은 추가 지원',
#  "신규 확진 26% '델타 변이'…2개의 미국될 것",
#  '이재명, 대선 출마 선언…불공정·양극화 해결',
#  '전염력 높은 코로나19 델타변이 감염자 500여명… “수도권 확산에 영향 미쳤을 가능성”',
#  '레고켐·티움·인트론...바이오주 일제히 급등',
#  '北, 코로나에 뚫렸나…김정은 “방역관련 중대사건 발생”',
#  '김정은, 방역 내세워 대대적 숙청… 軍서열 1위 리병철 해임된듯',
#  'G2 바라보는 국제사회의 엇갈린 시선…中 이미지 ‘최악’ vs 美는 급상승',
#  '지난해 매출 4억원 이상 소상공인, 최대 900만원 받는다 [2차 추경]',
#  '적자국채 없지만 재정의존증 심화...선별지원 기준 논란 점화[2차 추경 국무회의 통과]',
#  '목재 가격 6월 한달간 40% 이상 하락…월간 하락폭 역대 최대',
#  '국제사회, 엇갈린 ‘G2 시선’...中엔 거리두고 美엔 밀착하고',
#  '적자국채 추가발행 없지만 재정의존증 심화…선별지원 기준 등 논란 불가피 [2차 추경]',
#  '국민취업지원제도 지원 대상 확대…재산 4억원 청년, 취업경험자도 지원',
#  '유럽 ‘델타 변이’ 확산차단 총력...전문가 “이미 늦었다”',
#  '할인율 80%...편의점, 배보다 큰 ‘배꼽 세일’ 대전',
#  '민주 공중전...국민의힘은 장외전',
#  '민주 공중전 · 국힘 장외전… 대선판도, 남은 100일에 갈린다',
#  '천덕꾸러기 펀드의 귀환…펀드 설정액 사상 첫 700조 돌파',
#  '[그래픽 뉴스] 코로나19 신규 확진자 지역별로 살펴보니',
#  '따뜻한 해양경찰 수사개혁의 소망',
#  '미국·캐나다 서부, 폭염에 수백 명 사망...정전·산불도 잇따라',
#  "백신 접종자 '실외 노마스크' 허용 첫날 아직은...",
#  '[2차 추경]코로나 재난지원금, 누가 언제 얼마 받나',
#  '올림픽 축구엔트리 22명으로 확대...내일 추가 4명 발표',
#  '남부발전, 불필요한 규제 없애고 中企 활력 돕는다',
#  '부산대, 대학 발전기금 모금도 SNS 홍보시대',
#  '부산 중구 준사례관리자 ‘행복비추미’ 보수교육 실시',
#  "경기지역화폐 31개 시·군 데이트 시즌2' 용인시편",
#  '구포3동 (사)시랑골 복지후원회, 이웃돕기 성금 기탁',
#  '새로운 거제 미래 10년 청사진 ‘순항’']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
train_data['label'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
train_data['label'].value_counts()
# Out:
#  0    677
#  1     66
# -1     57
# Name: label, dtype: int64

# %%
test_data['label'].value_counts()
# Out:
#  0    170
# -1     17
#  1     13
# Name: label, dtype: int64

# %%
print(train_data.groupby('label').size().reset_index(name='count'))
print(test_data.groupby('label').size().reset_index(name='count'))
# Out:
#    label  count
# 0     -1     57
# 1      0    677
# 2      1     66
#    label  count
# 0     -1     17
# 1      0    170
# 2      1     13

# %% [markdown]
# ---

# %%
stopwords = ['의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다']

# %%
import konlpy
from konlpy.tag import Okt
okt = Okt()
X_train = []
for sentence in train_data['title']:
  temp_X = []
  temp_X = okt.morphs(sentence, stem=True) # 토큰화
  temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
  X_train.append(temp_X)
  
X_test = []
for sentence in test_data['title']:
  temp_X = []
  temp_X = okt.morphs(sentence, stem=True) # 토큰화
  temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
  X_test.append(temp_X)

# %%
from keras.preprocessing.text import Tokenizer
max_words = 35000
tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
print("제목의 최대 길이 : ", max(len(l) for l in X_train))
print("제목의 평균 길이 : ", sum(map(len, X_train))/ len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of Data')
plt.ylabel('number of Data')
plt.show()
# Out:
# 제목의 최대 길이 :  27
# 제목의 평균 길이 :  12.79625

# %%
print("제목의 최대 길이 : ", max(len(l) for l in X_test))
print("제목의 평균 길이 : ", sum(map(len, X_test))/ len(X_test))
plt.hist([len(s) for s in X_test], bins=50)
plt.xlabel('length of Data')
plt.ylabel('number of Data')
plt.show()
# Out:
# 제목의 최대 길이 :  22
# 제목의 평균 길이 :  10.165

# %%
import numpy as np

y_train = []
y_test = []



for i in range(len(train_data['label'])):
  if train_data['label'].iloc[i] == 1:
    y_train.append([0, 0, 1])
  elif train_data['label'].iloc[i] == 0:
    y_train.append([0, 1, 0])
  elif train_data['label'].iloc[i] == -1:
    y_train.append([1, 0, 0])

for i in range(len(test_data['label'])):
  if test_data['label'].iloc[i] == 1:
    y_test.append([0, 0, 1])
  elif test_data['label'].iloc[i] == 0:
    y_test.append([0, 1, 0])
  elif test_data['label'].iloc[i] == -1:
    y_test.append([1, 0, 0])

y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ---

# %%
from keras.layers import Embedding, Dense, LSTM
from keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_len = 20 # 전체 데이터의 길이를 20로 맞춘다

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(max_words, 100))
model.add(LSTM(128))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 72/72 [==============================] - 3s 23ms/step - loss: 0.6014 - accuracy: 0.8361 - val_loss: 0.4720 - val_accuracy: 0.8625
# Epoch 2/10
# 72/72 [==============================] - 1s 17ms/step - loss: 0.3898 - accuracy: 0.8611 - val_loss: 0.5053 - val_accuracy: 0.9000
# Epoch 3/10
# 72/72 [==============================] - 1s 20ms/step - loss: 0.1633 - accuracy: 0.9611 - val_loss: 0.7299 - val_accuracy: 0.8625
# Epoch 4/10
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0756 - accuracy: 0.9708 - val_loss: 0.6783 - val_accuracy: 0.8375
# Epoch 5/10
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0168 - accuracy: 0.9986 - val_loss: 0.7947 - val_accuracy: 0.8375
# Epoch 6/10
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0159 - accuracy: 0.9972 - val_loss: 0.9146 - val_accuracy: 0.8000
# Epoch 7/10
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.7661 - val_accuracy: 0.8500
# Epoch 8/10
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0029 - accuracy: 0.9986 - val_loss: 0.8624 - val_accuracy: 0.8500
# Epoch 9/10
# 72/72 [==============================] - 1s 18ms/step - loss: 0.0021 - accuracy: 0.9986 - val_loss: 0.8634 - val_accuracy: 0.8500
# Epoch 10/10
# 72/72 [==============================] - 1s 18ms/step - loss: 5.5276e-04 - accuracy: 1.0000 - val_loss: 0.9007 - val_accuracy: 0.8500

# %%
predict = model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 5ms/step

# %%
import numpy as np
predict_labels = np.argmax(predict, axis=1)
original_labels = np.argmax(y_test, axis=1)

# %%
for i in range(30):
  print("기사제목 : ", test_data['title'].iloc[i], "/\t 원래 라벨 : ", original_labels[i], "/\t예측한 라벨 : ", predict_labels[i])
# Out:
# 기사제목 :  부산성의신협, 연지동 ‘진구네 곳간’에 200만 원 상당 성품 후원 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  연산6동, 취약계층 '행복비타민 나눔' 사업 실시 /	 원래 라벨 :  0 /	예측한 라벨 :  1
# 기사제목 :  김해시, 소규모 아파트 ‘찾아가는 현장컨설팅’ 제공 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  김해시 화정글샘도서관, ‘시노래 콘서트’ 개최 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  김해시, 스마트 건강관리서비스 운영을 위한 업무협약 체결 /	 원래 라벨 :  2 /	예측한 라벨 :  2
# 기사제목 :  코이카, 전 세계가 함께하는 글로벌 서포터즈 ‘WeKO 3기’ 모집 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  비행기 사들이고 노선 확대… 항공사 정상화 날개 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  ‘김학의 출금 관여’ 기소된 이광철 사의…“검찰, 부당한 결정” /	 원래 라벨 :  0 /	예측한 라벨 :  0
# 기사제목 :  [아주 정확한 팩트체크] 김정은 '중대사건' 질책 뒤 코로나19 사령탑 줄줄이 해임? /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  마스크만 쓰고있어도 코로나19 감염 여부 확인 가능해진다 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  경남도교육청 소속 공공도서관 확대 개방 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  ‘탕핑’이 뭐길래...中공산당이 놀라 금기어로 정한 이 말 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  주한미군, 10명 추가 확진...누적 953명 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  도로공사 제20회 길 사진 공모전 개최 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  신규 확진 이틀연속 700명대…국내발생 85% '수도권'(상보) /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  군 장병 오늘부터 야외체육시설 '노마스크'로 이용 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  '놀면 뭐하니?' 100회 맞이 콘서트, SG워너비·빅마마·V.O.S 참여 확정 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  코로나 블루 겪는 청년층에 심리지원 서비스 제공 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  무더위엔 역시 삼계탕…롯데홈쇼핑에서 간편하게 먹자 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  진원생명과학 주가 1%↑…경구용 코로나 치료제 변이에도 효과 확인 '강세' /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  [더벨]넥스턴바이오, 바이오 사업 진격…中 큰손 잡았다 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  신규 환자 762명...이틀째 700명대 확산 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  울산시 민생노동특보에 김광식 전 현대차 노조위원장 임명 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  신규확진 이틀째 700명대…지역발생 85%가 수도권 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  정부, 33조 슈퍼추경안 의결…김 총리 포용적 회복 노력 필요 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  경기도시장상권진흥원, 경기연구원과 소상공인 정책 '세밀한 분석자료' 공동연구 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  울산시 민생노동특보에 김광식 전 현대차 노조위원장 /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  “알바 뽑고 식자재 대량 주문했는데”… ‘5인 금지’ 연장에 자영업자 ‘멘붕’ /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  포퓰리즘이란 괴물…키운 곳도 정치, 막을 곳도 정치 [Big Picture] /	 원래 라벨 :  1 /	예측한 라벨 :  1
# 기사제목 :  중진공, 중소벤처 수출 지원 위한 ‘해외거점 전략회의’ 개최 /	 원래 라벨 :  1 /	예측한 라벨 :  1

# %%
sum(predict_labels == original_labels) / len(original_labels)
# Out:
# 0.86
